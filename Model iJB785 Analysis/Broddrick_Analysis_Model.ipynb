# %% [markdown]
# # Analysis for Model iJB785 (Cyanobacterial metabolism for *Synechococcus elongatus* **PCC 7942**)
# ---
# ### Unique attributes of cyanobacterial metabolism revealed by improved genome-scale metabolic modeling and essential gene analysis
#
# #### Jared T. Broddrick (2016)
# ###### Doi: www.pnas.org/cgi/doi/10.1073/pnas.1613446113

# %% [markdown]
# ### **1.** Import the required packages and first configuration

# %%
from importlib_metadata import files
from pathlib import Path
#from cobra import Reaction, Metabolite
import pandas
import csv
import cobra

# %% [markdown]
# **1.1.** Getting the model path

# %%
Here = Path().absolute()
ModelPath = str(Here) + '/Model_iJB785.mat'

print(ModelPath)
# Out:
# /mnt/c/users/flron/OneDrive/Tesis/Cobrapy Model Development/Models Test/Model_iJB785.mat

# %% [markdown]
# **1.2.** Import the model into the environment

# %%
model = cobra.io.load_matlab_model(ModelPath)

# %% [markdown]
# **1.3.** Define the configuration singleton
# **1.4.** Select the Solver

# %%
cobra_config = cobra.Configuration()
cobra_config.solver = "glpk_exact"

# %% [markdown]
# ### **2.** Getting the required reactions
# ---
#  The purpose of this section is to <u> get all the reactions involved in</u> the *photophosphorylation process*, the __light reactions__, the reactions of *ROS* and the __pigment metabolism__ i

# %% [markdown]
# **2.1** Define a Unique function to filter a sorted list of elements

# %%
def unique(list1):

    # insert the list to the set
    list_set = set(list1)
    # convert the set to the list
    unique_list = sorted(list(list_set), key=str.lower)
    
    return unique_list

# %% [markdown]
# **2.2** Print all subsystems present inside the model

# %%
Subsyst = unique([rxn_i.subsystem for rxn_i in model.reactions])

# %% [markdown]
# **2.3** Place the model subsystems inside a text file

# %%
with open(str(Here) + "/SubsystemsCobra.txt", "w", encoding="utf-8") as f:
    count = 0
    for sys_i in Subsyst:
        count +=1
        f.write("%i. %s" % (count, "{"+sys_i+"}\n"))

# %% [markdown]
# **2.4** Create a list of desired susbsystems to select the specific reactions

# %%
Subsyst_2_analysis = [
    'Biomass and maintenance functions',
    'Carotenoid biosynthesis',
    'Photosynthesis/respiration'
]

Subsyst_2_analysis
# Out:
# ['Biomass and maintenance functions',
#  'Carotenoid biosynthesis',
#  'Photosynthesis/respiration']

# %% [markdown]
# **2.5** Make a reactions list from the subsystems list beforementioned
#
# <p style="font-size:10pt">Get the reactions classified in those subsystems </p>

# %% [markdown]
# ###### Few code to test

# %%
ObjReact = model.reactions.CYTBD4cm

if ObjReact.subsystem in Subsyst_2_analysis:
    print("✔ %s reaction is in subsystems list" % ObjReact.name)
else:
    print("✘ %s reaction isn't in the subsystem list" % ObjReact.name)
# Out:
# ✔ Cytochrome bd oxidase (plastoquinone utilizing, non-proton translocating) reaction is in subsystems list

# %%
RxnVect = {rxn_i.name: rxn_i for rxn_i in model.reactions if rxn_i.subsystem in Subsyst_2_analysis}

RxnVect = dict(sorted(RxnVect.items()))

RxnVect
# Out:
# {'15-cis-phytoene:plastoquinone oxidoreductase': <Reaction PHYPQOX at 0x7f3f5b0bda00>,
#  '7,9,7,9-tetracis-lycopene cis-trans-isomerase': <Reaction PLYCOI at 0x7f3f5b0bdf10>,
#  '7,9,9-tricis-neurosporene:quinone oxidoreductase': <Reaction ZCARDS at 0x7f3f5b0bdd60>,
#  '9,15,9-tricis-zeta-carotene cis-trans-isomerase': <Reaction ZISO at 0x7f3f5b0bdbb0>,
#  'ATP synthase (thylakoid membrane)': <Reaction ATPSum at 0x7f3f5b0e6790>,
#  'Beta-carotene hydroxylase (beta-cryptoxanthin forming)': <Reaction BCAROHX at 0x7f3f5b0e6d30>,
#  'Beta-carotene hydroxylase (zeaxanthin forming)': <Reaction BCAROHX2 at 0x7f3f5b1c0a60>,
#  'Bidirectional [NiFe] Hydrogenase': <Reaction NAD_H2 at 0x7f3f5b158a30>,
#  'BioLip': <Reaction BM_MEM_LIPIDS at 0x7f3f5b149d60>,
#  'Biomass objective function': <Reaction BOF at 0x7f3f5b200d60>,
#  'Biomass: Cell wall (LPS and peptidoglycan)': <Reaction BM_CELL_WALL at 0x7f3f5b1539a0>,
#  'Biomass: DNA': <Reaction BM_DNA at 0x7f3f5b196e50>,
#  'Biomass: RNA': <Reaction BM_RNA at 0x7f3f5b0ec640>,
#  'Biomass: carbohydrates (storage and misc.)': <Reaction BM_CARB at 0x7f3f5b105c70>,
#  'Biomass: cofactor pool': <Reaction BM_COFACTORS at 0x7f3f5b1871f0>,
#  'Biomass: pigments and xanthophylls': <Reaction BM_PIGMENTS at 0x7f3f5b1f3ac0>,
#  'Biomass: protein': <Reaction BM_PROTEIN at 0x7f3f5b0dfac0>,
#  'Caloxanthin hydroxylase (nostoxanthin forming)': <Reaction CXANHX at 0x7f3f5b01e070>,
#  'Carbonic anhydrase': <Reaction HCO3E_1_cx at 0x7f3f5b18cb20>,
#  'Catalase': <Reaction CAT at 0x7f3f5b1050a0>,
#  'Cytb6f complex': <Reaction CBFCum at 0x7f3f5b0a5a60>,
#  'Cytochrome aa3 oxidase (plastocyanin utilizing, H+/e-:  0.9)': <Reaction CYOOum at 0x7f3f5b1c7d00>,
#  'Cytochrome bd oxidase (plastoquinone utilizing, non-proton translocating)': <Reaction CYTBD4um at 0x7f3f5b0fed60>,
#  'Energy transfer (Allophycocyanin to PSII ChlA Qy)': <Reaction ETAPCPSII at 0x7f3f5afe0280>,
#  'Energy transfer (Beta carotene to ChlA Qy)': <Reaction ETBCARO at 0x7f3f5b01ed00>,
#  'Energy transfer (ChlA Soret to ChlA Qy)': <Reaction ETCHLAS at 0x7f3f5b01ec70>,
#  'Energy transfer (Phycocyanin to allophycocyanin)': <Reaction ETCPC at 0x7f3f5b01ed90>,
#  'Ferredoxin:NADPH oxidoreductase': <Reaction FNOR at 0x7f3f5b1cdaf0>,
#  'Geranylgeranyl-diphosphate geranylgeranyl-diphosphate geranylgeranyltransferase': <Reaction PHYTES at 0x7f3f5b200850>,
#  'Lycopene cyclase (beta-carotene producing)': <Reaction LYCBC2 at 0x7f3f5b230d00>,
#  'Lycopene cyclase (gamma-carotene producing)': <Reaction LYCBC1 at 0x7f3f5b15ef10>,
#  'Mehler reaction': <Reaction MEHLER at 0x7f3f5b191640>,
#  'Modeling: ATP Maintenance': <Reaction ATPM at 0x7f3f5b203d00>,
#  'Modeling: Non-growth associated maintenance': <Reaction NGAM at 0x7f3f5affca30>,
#  'NAD transhydrogenase': <Reaction NADTRHD at 0x7f3f5b0df5b0>,
#  'NAD(P)H dehydrogenase (plastoquinone-8 & 4 protons)( Thylakoid)': <Reaction NDH-1(2)um at 0x7f3f5b067610>,
#  'NAD(P)H dehydrogenase, carbon dioxide coupled (plastoquinone-8 & 4 protons)( Thylakoid)': <Reaction NDH-1(3)um at 0x7f3f5b067be0>,
#  'NADH:plastoquinone reductase (non-electrogenic)': <Reaction NDHPQRcm at 0x7f3f5b14ff70>,
#  'Neurosporene oxidoreductase': <Reaction NOR at 0x7f3f5b2419a0>,
#  'Non-growth associated maintenance: PSII D1 protein repair': <Reaction NGAM_D1um at 0x7f3f5affc280>,
#  'Photon absorption (400nm-420nm)': <Reaction PHOA410um at 0x7f3f5b01e160>,
#  'Photon absorption (420nm-440nm) ': <Reaction PHOA430um at 0x7f3f5b01e0a0>,
#  'Photon absorption (440nm-460nm) ': <Reaction PHOA450um at 0x7f3f5b01e3d0>,
#  'Photon absorption (460nm-480nm) ': <Reaction PHOA470um at 0x7f3f5b01e4f0>,
#  'Photon absorption (480-500nm) ': <Reaction PHOA490um at 0x7f3f5b01e5b0>,
#  'Photon absorption (500nm-520nm)': <Reaction PHOA510um at 0x7f3f5b01e640>,
#  'Photon absorption (520nm-540nm) ': <Reaction PHOA530um at 0x7f3f5b01e6d0>,
#  'Photon absorption (540nm-560nm) ': <Reaction PHOA550um at 0x7f3f5b01e760>,
#  'Photon absorption (560nm-580nm) ': <Reaction PHOA570um at 0x7f3f5b01e7f0>,
#  'Photon absorption (580-600nm) ': <Reaction PHOA590um at 0x7f3f5b01e880>,
#  'Photon absorption (600nm-620nm)': <Reaction PHOA610um at 0x7f3f5b01e910>,
#  'Photon absorption (620nm-640nm) ': <Reaction PHOA630um at 0x7f3f5b01e9a0>,
#  'Photon absorption (640nm-660nm) ': <Reaction PHOA650um at 0x7f3f5b01ea30>,
#  'Photon absorption (660nm-680nm) ': <Reaction PHOA670um at 0x7f3f5b01eac0>,
#  'Photon absorption (680-700nm) ': <Reaction PHOA690um at 0x7f3f5b01eb50>,
#  'Photosystem I': <Reaction PSIum at 0x7f3f5b1d4c40>,
#  'Photosystem I charge recombination': <Reaction PSICRum at 0x7f3f5affc340>,
#  'Photosystem I charge separation': <Reaction PSICSum at 0x7f3f5afe03a0>,
#  'Photosystem II': <Reaction PSIIum at 0x7f3f5b09cb50>,
#  'Photosystem II charge recombination': <Reaction PSIICRum at 0x7f3f5affc3d0>,
#  'Photosystem II charge separation': <Reaction PSIICSum at 0x7f3f5afe0c70>,
#  'Phytoene dehydrogenase': <Reaction PDS1 at 0x7f3f5b0dffd0>,
#  'Phytofluene dehydrogenase': <Reaction PDS2 at 0x7f3f5b1f92e0>,
#  'Pigment de-excitation (xanthophylls)': <Reaction DEXZEAX at 0x7f3f5afe89d0>,
#  'Prephytoene diphosphate geranylgeranyl-diphosphategeranylgeranyltransferase': <Reaction PHYTES2 at 0x7f3f5b19c8e0>,
#  'State transition energy transfer (Allophycocyanin to PSI ChlA Qy)': <Reaction STACPSI at 0x7f3f5b027700>,
#  'State transition energy transfer (PSII ChlA Qy to PSI ChlA Qy)': <Reaction STCHLPSIum at 0x7f3f5afe8a60>,
#  'Succinate dehydrogenase (plastoquinone utilizing, thylakoid membrane localized)': <Reaction SUCDum at 0x7f3f5b17ddc0>,
#  'Superoxide dismutase': <Reaction SPODM at 0x7f3f5b12bdf0>,
#  'Thioredoxin:ferredoxin reductase': <Reaction TRDRf at 0x7f3f5b149b20>,
#  'Zeaxanthin hydroxylase (caloxanthin forming)': <Reaction ZXANHX at 0x7f3f5b015fd0>,
#  'Zeta-carotene desaturase': <Reaction ZDS at 0x7f3f5b130610>}

# %% [markdown]
# **2.6** Generate a __.csv__ file with the RxnVect Main Information

# %% [markdown]
# <p style="font-size:10pt">A short test to generate the Names of each reaction as Vector</p>

# %%
RxnNames = list(RxnVect.keys())

count = 0
for rxn in RxnNames:
    count += 1

print(count)
RxnNames
# Out:
# 72
# ['15-cis-phytoene:plastoquinone oxidoreductase',
#  '7,9,7,9-tetracis-lycopene cis-trans-isomerase',
#  '7,9,9-tricis-neurosporene:quinone oxidoreductase',
#  '9,15,9-tricis-zeta-carotene cis-trans-isomerase',
#  'ATP synthase (thylakoid membrane)',
#  'Beta-carotene hydroxylase (beta-cryptoxanthin forming)',
#  'Beta-carotene hydroxylase (zeaxanthin forming)',
#  'Bidirectional [NiFe] Hydrogenase',
#  'BioLip',
#  'Biomass objective function',
#  'Biomass: Cell wall (LPS and peptidoglycan)',
#  'Biomass: DNA',
#  'Biomass: RNA',
#  'Biomass: carbohydrates (storage and misc.)',
#  'Biomass: cofactor pool',
#  'Biomass: pigments and xanthophylls',
#  'Biomass: protein',
#  'Caloxanthin hydroxylase (nostoxanthin forming)',
#  'Carbonic anhydrase',
#  'Catalase',
#  'Cytb6f complex',
#  'Cytochrome aa3 oxidase (plastocyanin utilizing, H+/e-:  0.9)',
#  'Cytochrome bd oxidase (plastoquinone utilizing, non-proton translocating)',
#  'Energy transfer (Allophycocyanin to PSII ChlA Qy)',
#  'Energy transfer (Beta carotene to ChlA Qy)',
#  'Energy transfer (ChlA Soret to ChlA Qy)',
#  'Energy transfer (Phycocyanin to allophycocyanin)',
#  'Ferredoxin:NADPH oxidoreductase',
#  'Geranylgeranyl-diphosphate geranylgeranyl-diphosphate geranylgeranyltransferase',
#  'Lycopene cyclase (beta-carotene producing)',
#  'Lycopene cyclase (gamma-carotene producing)',
#  'Mehler reaction',
#  'Modeling: ATP Maintenance',
#  'Modeling: Non-growth associated maintenance',
#  'NAD transhydrogenase',
#  'NAD(P)H dehydrogenase (plastoquinone-8 & 4 protons)( Thylakoid)',
#  'NAD(P)H dehydrogenase, carbon dioxide coupled (plastoquinone-8 & 4 protons)( Thylakoid)',
#  'NADH:plastoquinone reductase (non-electrogenic)',
#  'Neurosporene oxidoreductase',
#  'Non-growth associated maintenance: PSII D1 protein repair',
#  'Photon absorption (400nm-420nm)',
#  'Photon absorption (420nm-440nm) ',
#  'Photon absorption (440nm-460nm) ',
#  'Photon absorption (460nm-480nm) ',
#  'Photon absorption (480-500nm) ',
#  'Photon absorption (500nm-520nm)',
#  'Photon absorption (520nm-540nm) ',
#  'Photon absorption (540nm-560nm) ',
#  'Photon absorption (560nm-580nm) ',
#  'Photon absorption (580-600nm) ',
#  'Photon absorption (600nm-620nm)',
#  'Photon absorption (620nm-640nm) ',
#  'Photon absorption (640nm-660nm) ',
#  'Photon absorption (660nm-680nm) ',
#  'Photon absorption (680-700nm) ',
#  'Photosystem I',
#  'Photosystem I charge recombination',
#  'Photosystem I charge separation',
#  'Photosystem II',
#  'Photosystem II charge recombination',
#  'Photosystem II charge separation',
#  'Phytoene dehydrogenase',
#  'Phytofluene dehydrogenase',
#  'Pigment de-excitation (xanthophylls)',
#  'Prephytoene diphosphate geranylgeranyl-diphosphategeranylgeranyltransferase',
#  'State transition energy transfer (Allophycocyanin to PSI ChlA Qy)',
#  'State transition energy transfer (PSII ChlA Qy to PSI ChlA Qy)',
#  'Succinate dehydrogenase (plastoquinone utilizing, thylakoid membrane localized)',
#  'Superoxide dismutase',
#  'Thioredoxin:ferredoxin reductase',
#  'Zeaxanthin hydroxylase (caloxanthin forming)',
#  'Zeta-carotene desaturase']

# %% [markdown]
# Generate a list of Reaction IDs

# %%
RxnIDs = []

count = 0
for rxn in RxnVect.values():
    count += 1
    RxnIDs.append(rxn.id)

print(count)

RxnIDs
# Out:
# 72
# ['PHYPQOX',
#  'PLYCOI',
#  'ZCARDS',
#  'ZISO',
#  'ATPSum',
#  'BCAROHX',
#  'BCAROHX2',
#  'NAD_H2',
#  'BM_MEM_LIPIDS',
#  'BOF',
#  'BM_CELL_WALL',
#  'BM_DNA',
#  'BM_RNA',
#  'BM_CARB',
#  'BM_COFACTORS',
#  'BM_PIGMENTS',
#  'BM_PROTEIN',
#  'CXANHX',
#  'HCO3E_1_cx',
#  'CAT',
#  'CBFCum',
#  'CYOOum',
#  'CYTBD4um',
#  'ETAPCPSII',
#  'ETBCARO',
#  'ETCHLAS',
#  'ETCPC',
#  'FNOR',
#  'PHYTES',
#  'LYCBC2',
#  'LYCBC1',
#  'MEHLER',
#  'ATPM',
#  'NGAM',
#  'NADTRHD',
#  'NDH-1(2)um',
#  'NDH-1(3)um',
#  'NDHPQRcm',
#  'NOR',
#  'NGAM_D1um',
#  'PHOA410um',
#  'PHOA430um',
#  'PHOA450um',
#  'PHOA470um',
#  'PHOA490um',
#  'PHOA510um',
#  'PHOA530um',
#  'PHOA550um',
#  'PHOA570um',
#  'PHOA590um',
#  'PHOA610um',
#  'PHOA630um',
#  'PHOA650um',
#  'PHOA670um',
#  'PHOA690um',
#  'PSIum',
#  'PSICRum',
#  'PSICSum',
#  'PSIIum',
#  'PSIICRum',
#  'PSIICSum',
#  'PDS1',
#  'PDS2',
#  'DEXZEAX',
#  'PHYTES2',
#  'STACPSI',
#  'STCHLPSIum',
#  'SUCDum',
#  'SPODM',
#  'TRDRf',
#  'ZXANHX',
#  'ZDS']

# %%
RxnSys = []

count = 0
for rxn in RxnVect.values():
    count += 1
    RxnSys.append(rxn.subsystem)

print(count)

RxnSys
# Out:
# 72
# ['Carotenoid biosynthesis',
#  'Carotenoid biosynthesis',
#  'Carotenoid biosynthesis',
#  'Carotenoid biosynthesis',
#  'Photosynthesis/respiration',
#  'Carotenoid biosynthesis',
#  'Carotenoid biosynthesis',
#  'Photosynthesis/respiration',
#  'Biomass and maintenance functions',
#  'Biomass and maintenance functions',
#  'Biomass and maintenance functions',
#  'Biomass and maintenance functions',
#  'Biomass and maintenance functions',
#  'Biomass and maintenance functions',
#  'Biomass and maintenance functions',
#  'Biomass and maintenance functions',
#  'Biomass and maintenance functions',
#  'Carotenoid biosynthesis',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Carotenoid biosynthesis',
#  'Carotenoid biosynthesis',
#  'Carotenoid biosynthesis',
#  'Photosynthesis/respiration',
#  'Biomass and maintenance functions',
#  'Biomass and maintenance functions',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Carotenoid biosynthesis',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Carotenoid biosynthesis',
#  'Carotenoid biosynthesis',
#  'Photosynthesis/respiration',
#  'Carotenoid biosynthesis',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Photosynthesis/respiration',
#  'Carotenoid biosynthesis',
#  'Carotenoid biosynthesis']

# %% [markdown]
# <p style="font-size:10pt">Trying with csv </p>

# %%
with open(str(Here) + "/ReactionsBroddrick.csv", "w", encoding="utf-8") as csv_f:
    fieldnames = ['Name', 'ID', 'Subsystem']
    fc = csv.DictWriter(csv_f, fieldnames=fieldnames)
    fc.writeheader()
    count = 0
    for rxn, id, sys in zip(RxnNames, RxnIDs, RxnSys):
        fc.writerow({'Name': rxn, 'ID': id, 'Subsystem': sys})
        count += 1

# %% [markdown]
# <p style="font-size:10pt">Trying with pandas </p>

# %%
df = pandas.DataFrame({'Name': RxnNames, 'ID': RxnIDs, 'Subsystem': RxnSys})
df
# Out:
#                                                  Name       ID  \
# 0        15-cis-phytoene:plastoquinone oxidoreductase  PHYPQOX
# 1       7,9,7,9-tetracis-lycopene cis-trans-isomerase   PLYCOI
# 2    7,9,9-tricis-neurosporene:quinone oxidoreductase   ZCARDS
# 3     9,15,9-tricis-zeta-carotene cis-trans-isomerase     ZISO
# 4                   ATP synthase (thylakoid membrane)   ATPSum
# ..                                                ...      ...
# 67  Succinate dehydrogenase (plastoquinone utilizi...   SUCDum
# 68                               Superoxide dismutase    SPODM
# 69                   Thioredoxin:ferredoxin reductase    TRDRf
# 70       Zeaxanthin hydroxylase (caloxanthin forming)   ZXANHX
# 71                           Zeta-carotene desaturase      ZDS
#
#                      Subsystem
# 0      Carotenoid biosynthesis
# 1      Carotenoid biosynthesis
# 2      Carotenoid biosynthesis
# 3      Carotenoid biosynthesis
# 4   Photosynthesis/respiration
# ..                         ...
# 67  Photosynthesis/respiration
# 68  Photosynthesis/respiration
# 69  Photosynthesis/respiration
# 70     Carotenoid biosynthesis
# 71     Carotenoid biosynthesis
#
# [72 rows x 3 columns]

# %%
df.to_csv(str(Here) + "/ReactionsBroddrickPandas.csv", index=False)

# %% [markdown]
# ### **3.** Generating the model with the previous selected reactions
# ---
#  The purpose of this section is to <u> get all information related with</u> the *photophosphorylation process*, how was handled the __light reactions__, the reactions of *ROS* and the __pigment metabolism__ inside the model. Thus, one way to reach this objective is to reduce or simplify the model just to the selected reactions vector.

# %% [markdown]
# **3.1** Cure the reaction vector by discarding non-important reactions for the analysis

# %%
delRxn = [
    'BioLip',
    'Biomass objective function',
    'Biomass: Cell wall (LPS and peptidoglycan)',
    'Biomass: DNA',
    'Biomass: RNA',
    'Biomass: carbohydrates (storage and misc.)',
    'Biomass: cofactor pool',
    'Biomass: protein',
    'Geranylgeranyl-diphosphate geranylgeranyl-diphosphate geranylgeranyltransferase',
    'Modeling: ATP Maintenance',
    'Neurosporene oxidoreductase',
    'Phytoene dehydrogenase',
    'Phytofluene dehydrogenase',
    'Prephytoene diphosphate geranylgeranyl-diphosphategeranylgeranyltransferase',
    'Zeta-carotene desaturase'
]

for rxn in delRxn:
    del RxnVect[rxn]

RxnVect
# Out:
# {'15-cis-phytoene:plastoquinone oxidoreductase': <Reaction PHYPQOX at 0x7f3f5b0bda00>,
#  '7,9,7,9-tetracis-lycopene cis-trans-isomerase': <Reaction PLYCOI at 0x7f3f5b0bdf10>,
#  '7,9,9-tricis-neurosporene:quinone oxidoreductase': <Reaction ZCARDS at 0x7f3f5b0bdd60>,
#  '9,15,9-tricis-zeta-carotene cis-trans-isomerase': <Reaction ZISO at 0x7f3f5b0bdbb0>,
#  'ATP synthase (thylakoid membrane)': <Reaction ATPSum at 0x7f3f5b0e6790>,
#  'Beta-carotene hydroxylase (beta-cryptoxanthin forming)': <Reaction BCAROHX at 0x7f3f5b0e6d30>,
#  'Beta-carotene hydroxylase (zeaxanthin forming)': <Reaction BCAROHX2 at 0x7f3f5b1c0a60>,
#  'Bidirectional [NiFe] Hydrogenase': <Reaction NAD_H2 at 0x7f3f5b158a30>,
#  'Biomass: pigments and xanthophylls': <Reaction BM_PIGMENTS at 0x7f3f5b1f3ac0>,
#  'Caloxanthin hydroxylase (nostoxanthin forming)': <Reaction CXANHX at 0x7f3f5b01e070>,
#  'Carbonic anhydrase': <Reaction HCO3E_1_cx at 0x7f3f5b18cb20>,
#  'Catalase': <Reaction CAT at 0x7f3f5b1050a0>,
#  'Cytb6f complex': <Reaction CBFCum at 0x7f3f5b0a5a60>,
#  'Cytochrome aa3 oxidase (plastocyanin utilizing, H+/e-:  0.9)': <Reaction CYOOum at 0x7f3f5b1c7d00>,
#  'Cytochrome bd oxidase (plastoquinone utilizing, non-proton translocating)': <Reaction CYTBD4um at 0x7f3f5b0fed60>,
#  'Energy transfer (Allophycocyanin to PSII ChlA Qy)': <Reaction ETAPCPSII at 0x7f3f5afe0280>,
#  'Energy transfer (Beta carotene to ChlA Qy)': <Reaction ETBCARO at 0x7f3f5b01ed00>,
#  'Energy transfer (ChlA Soret to ChlA Qy)': <Reaction ETCHLAS at 0x7f3f5b01ec70>,
#  'Energy transfer (Phycocyanin to allophycocyanin)': <Reaction ETCPC at 0x7f3f5b01ed90>,
#  'Ferredoxin:NADPH oxidoreductase': <Reaction FNOR at 0x7f3f5b1cdaf0>,
#  'Lycopene cyclase (beta-carotene producing)': <Reaction LYCBC2 at 0x7f3f5b230d00>,
#  'Lycopene cyclase (gamma-carotene producing)': <Reaction LYCBC1 at 0x7f3f5b15ef10>,
#  'Mehler reaction': <Reaction MEHLER at 0x7f3f5b191640>,
#  'Modeling: Non-growth associated maintenance': <Reaction NGAM at 0x7f3f5affca30>,
#  'NAD transhydrogenase': <Reaction NADTRHD at 0x7f3f5b0df5b0>,
#  'NAD(P)H dehydrogenase (plastoquinone-8 & 4 protons)( Thylakoid)': <Reaction NDH-1(2)um at 0x7f3f5b067610>,
#  'NAD(P)H dehydrogenase, carbon dioxide coupled (plastoquinone-8 & 4 protons)( Thylakoid)': <Reaction NDH-1(3)um at 0x7f3f5b067be0>,
#  'NADH:plastoquinone reductase (non-electrogenic)': <Reaction NDHPQRcm at 0x7f3f5b14ff70>,
#  'Non-growth associated maintenance: PSII D1 protein repair': <Reaction NGAM_D1um at 0x7f3f5affc280>,
#  'Photon absorption (400nm-420nm)': <Reaction PHOA410um at 0x7f3f5b01e160>,
#  'Photon absorption (420nm-440nm) ': <Reaction PHOA430um at 0x7f3f5b01e0a0>,
#  'Photon absorption (440nm-460nm) ': <Reaction PHOA450um at 0x7f3f5b01e3d0>,
#  'Photon absorption (460nm-480nm) ': <Reaction PHOA470um at 0x7f3f5b01e4f0>,
#  'Photon absorption (480-500nm) ': <Reaction PHOA490um at 0x7f3f5b01e5b0>,
#  'Photon absorption (500nm-520nm)': <Reaction PHOA510um at 0x7f3f5b01e640>,
#  'Photon absorption (520nm-540nm) ': <Reaction PHOA530um at 0x7f3f5b01e6d0>,
#  'Photon absorption (540nm-560nm) ': <Reaction PHOA550um at 0x7f3f5b01e760>,
#  'Photon absorption (560nm-580nm) ': <Reaction PHOA570um at 0x7f3f5b01e7f0>,
#  'Photon absorption (580-600nm) ': <Reaction PHOA590um at 0x7f3f5b01e880>,
#  'Photon absorption (600nm-620nm)': <Reaction PHOA610um at 0x7f3f5b01e910>,
#  'Photon absorption (620nm-640nm) ': <Reaction PHOA630um at 0x7f3f5b01e9a0>,
#  'Photon absorption (640nm-660nm) ': <Reaction PHOA650um at 0x7f3f5b01ea30>,
#  'Photon absorption (660nm-680nm) ': <Reaction PHOA670um at 0x7f3f5b01eac0>,
#  'Photon absorption (680-700nm) ': <Reaction PHOA690um at 0x7f3f5b01eb50>,
#  'Photosystem I': <Reaction PSIum at 0x7f3f5b1d4c40>,
#  'Photosystem I charge recombination': <Reaction PSICRum at 0x7f3f5affc340>,
#  'Photosystem I charge separation': <Reaction PSICSum at 0x7f3f5afe03a0>,
#  'Photosystem II': <Reaction PSIIum at 0x7f3f5b09cb50>,
#  'Photosystem II charge recombination': <Reaction PSIICRum at 0x7f3f5affc3d0>,
#  'Photosystem II charge separation': <Reaction PSIICSum at 0x7f3f5afe0c70>,
#  'Pigment de-excitation (xanthophylls)': <Reaction DEXZEAX at 0x7f3f5afe89d0>,
#  'State transition energy transfer (Allophycocyanin to PSI ChlA Qy)': <Reaction STACPSI at 0x7f3f5b027700>,
#  'State transition energy transfer (PSII ChlA Qy to PSI ChlA Qy)': <Reaction STCHLPSIum at 0x7f3f5afe8a60>,
#  'Succinate dehydrogenase (plastoquinone utilizing, thylakoid membrane localized)': <Reaction SUCDum at 0x7f3f5b17ddc0>,
#  'Superoxide dismutase': <Reaction SPODM at 0x7f3f5b12bdf0>,
#  'Thioredoxin:ferredoxin reductase': <Reaction TRDRf at 0x7f3f5b149b20>,
#  'Zeaxanthin hydroxylase (caloxanthin forming)': <Reaction ZXANHX at 0x7f3f5b015fd0>}

# %%
RxnNames = list(RxnVect.keys())

RxnIDs = []
RxnSys = []

count = 0
for rxn in RxnVect.values():
    count += 1
    RxnIDs.append(rxn.id)
    RxnSys.append(rxn.subsystem)


df = pandas.DataFrame({'Name': RxnNames, 'ID': RxnIDs, 'Subsystem': RxnSys})
df.to_csv(str(Here) + "/ReactionsBroddrickPandas.csv", index=False)

# %%
print(count)
# Out:
# 57

# %% [markdown]
# **3.2** Remove all reactions from the model, whose names are **not saved** in the reaction vector

# %% [markdown]
# <p style="font-size:10pt">Function to check the dimensions of the model</p>

# %%
def model_printProp():
    print(f'{len(model.reactions)} reactions initially')
    print(f'{len(model.metabolites)} metabolites initially')
    print(f'{len(model.genes)} genes initially')

model_printProp()
# Out:
# 850 reactions initially
# 768 metabolites initially
# 785 genes initially

# %% [markdown]
# <p style="font-size:10pt">Test to delete a reaction</p>

# %%
ObjReact = model.reactions.ACCOAC

ObjReact.remove_from_model()

model_printProp()
# Out:
# 849 reactions initially
# 768 metabolites initially
# 785 genes initially

# %% [markdown]
# Process to delete all reactions differ to RxnVect

# %%
def CleanRxn(Metmodel, RxnDict):
    RxnList = Metmodel.reactions
    length = len(RxnList)
    i = 0

    while i < length:
        if RxnList[i].name in RxnDict.keys():
            print("%s remained" % RxnList[i].id)
            i += 1
        else:
            print("%s deleted" % RxnList[i].id)
            RxnList[i].remove_from_model()
            length = len(RxnList)
            i = i
            print("     Reaction Array now has %i elements" % length)
            print("     i pointer is in position %i with id: %s" % (i, RxnList[i].id))

# %%
CleanRxn(model, RxnVect)

model_printProp()

model.reactions
# Out:
# QULNS deleted
#      Reaction Array now has 849 elements
#      i pointer is in position 0 with id: ORNDC
# ORNDC deleted
#      Reaction Array now has 848 elements
#      i pointer is in position 0 with id: LEUTA
# LEUTA deleted
#      Reaction Array now has 847 elements
#      i pointer is in position 0 with id: MSBENZMT
# MSBENZMT deleted
#      Reaction Array now has 846 elements
#      i pointer is in position 0 with id: DESAT18a
# DESAT18a deleted
#      Reaction Array now has 845 elements
#      i pointer is in position 0 with id: FUM
# FUM deleted
#      Reaction Array now has 844 elements
#      i pointer is in position 0 with id: PHYFXOR
# PHYFXOR deleted
#      Reaction Array now has 843 elements
#      i pointer is in position 0 with id: VPAMTr
# VPAMTr deleted
#      Reaction Array now has 842 elements
#      i pointer is in position 0 with id: GLYCL
# GLYCL deleted
#      Reaction Array now has 841 elements
#      i pointer is in position 0 with id: NDPK7
# NDPK7 deleted
#      Reaction Array now has 840 elements
#      i pointer is in position 0 with id: GTPCI
# GTPCI deleted
#      Reaction Array now has 839 elements
#      i pointer is in position 0 with id: MTHFC
# MTHFC deleted
#      Reaction Array now has 838 elements
#      i pointer is in position 0 with id: LYCBC2
# LYCBC2 remained
# ORNTA deleted
#      Reaction Array now has 837 elements
#      i pointer is in position 1 with id: UPPDC1
# UPPDC1 deleted
#      Reaction Array now has 836 elements
#      i pointer is in position 1 with id: GARFT
# GARFT deleted
#      Reaction Array now has 835 elements
#      i pointer is in position 1 with id: H4THDPR
# H4THDPR deleted
#      Reaction Array now has 834 elements
#      i pointer is in position 1 with id: UDPG4E
# UDPG4E deleted
#      Reaction Array now has 833 elements
#      i pointer is in position 1 with id: GLCS3
# GLCS3 deleted
#      Reaction Array now has 832 elements
#      i pointer is in position 1 with id: ASPTA
# ASPTA deleted
#      Reaction Array now has 831 elements
#      i pointer is in position 1 with id: PRAGSr
# PRAGSr deleted
#      Reaction Array now has 830 elements
#      i pointer is in position 1 with id: ACKr
# ACKr deleted
#      Reaction Array now has 829 elements
#      i pointer is in position 1 with id: KAS14
# KAS14 deleted
#      Reaction Array now has 828 elements
#      i pointer is in position 1 with id: UDCPDPS
# UDCPDPS deleted
#      Reaction Array now has 827 elements
#      i pointer is in position 1 with id: GLNS
# GLNS deleted
#      Reaction Array now has 826 elements
#      i pointer is in position 1 with id: SHKK
# SHKK deleted
#      Reaction Array now has 825 elements
#      i pointer is in position 1 with id: G1PACT
# G1PACT deleted
#      Reaction Array now has 824 elements
#      i pointer is in position 1 with id: 5DOAN
# 5DOAN deleted
#      Reaction Array now has 823 elements
#      i pointer is in position 1 with id: OHPBAT
# OHPBAT deleted
#      Reaction Array now has 822 elements
#      i pointer is in position 1 with id: Htex
# Htex deleted
#      Reaction Array now has 821 elements
#      i pointer is in position 1 with id: 3HAD60
# 3HAD60 deleted
#      Reaction Array now has 820 elements
#      i pointer is in position 1 with id: PGI
# PGI deleted
#      Reaction Array now has 819 elements
#      i pointer is in position 1 with id: PNTK
# PNTK deleted
#      Reaction Array now has 818 elements
#      i pointer is in position 1 with id: 3OAR60
# 3OAR60 deleted
#      Reaction Array now has 817 elements
#      i pointer is in position 1 with id: ACGK
# ACGK deleted
#      Reaction Array now has 816 elements
#      i pointer is in position 1 with id: LEUabcpp
# LEUabcpp deleted
#      Reaction Array now has 815 elements
#      i pointer is in position 1 with id: G5SD
# G5SD deleted
#      Reaction Array now has 814 elements
#      i pointer is in position 1 with id: DTMPK
# DTMPK deleted
#      Reaction Array now has 813 elements
#      i pointer is in position 1 with id: NOR
# NOR deleted
#      Reaction Array now has 812 elements
#      i pointer is in position 1 with id: NDH-1(1)um
# NDH-1(1)um remained
# AOOA deleted
#      Reaction Array now has 811 elements
#      i pointer is in position 2 with id: CMPA
# CMPA deleted
#      Reaction Array now has 810 elements
#      i pointer is in position 2 with id: U23GAAT2
# U23GAAT2 deleted
#      Reaction Array now has 809 elements
#      i pointer is in position 2 with id: PGK
# PGK deleted
#      Reaction Array now has 808 elements
#      i pointer is in position 2 with id: IMPD
# IMPD deleted
#      Reaction Array now has 807 elements
#      i pointer is in position 2 with id: LPOR
# LPOR deleted
#      Reaction Array now has 806 elements
#      i pointer is in position 2 with id: CHRPL
# CHRPL deleted
#      Reaction Array now has 805 elements
#      i pointer is in position 2 with id: GCALDDy
# GCALDDy deleted
#      Reaction Array now has 804 elements
#      i pointer is in position 2 with id: RNDR1
# RNDR1 deleted
#      Reaction Array now has 803 elements
#      i pointer is in position 2 with id: AIRC2
# AIRC2 deleted
#      Reaction Array now has 802 elements
#      i pointer is in position 2 with id: MTAP
# MTAP deleted
#      Reaction Array now has 801 elements
#      i pointer is in position 2 with id: HEMEAS
# HEMEAS deleted
#      Reaction Array now has 800 elements
#      i pointer is in position 2 with id: DHORD3um
# DHORD3um deleted
#      Reaction Array now has 799 elements
#      i pointer is in position 2 with id: TRPS1
# TRPS1 deleted
#      Reaction Array now has 798 elements
#      i pointer is in position 2 with id: NNATr
# NNATr deleted
#      Reaction Array now has 797 elements
#      i pointer is in position 2 with id: 3OAR120
# 3OAR120 deleted
#      Reaction Array now has 796 elements
#      i pointer is in position 2 with id: HISTDb
# HISTDb deleted
#      Reaction Array now has 795 elements
#      i pointer is in position 2 with id: SPS
# SPS deleted
#      Reaction Array now has 794 elements
#      i pointer is in position 2 with id: ADCL
# ADCL deleted
#      Reaction Array now has 793 elements
#      i pointer is in position 2 with id: CYTK1
# CYTK1 deleted
#      Reaction Array now has 792 elements
#      i pointer is in position 2 with id: PSIum
# PSIum remained
# Cobalt2abcppI deleted
#      Reaction Array now has 791 elements
#      i pointer is in position 3 with id: THRS
# THRS deleted
#      Reaction Array now has 790 elements
#      i pointer is in position 3 with id: AOXPBDC
# AOXPBDC deleted
#      Reaction Array now has 789 elements
#      i pointer is in position 3 with id: NAMNPP
# NAMNPP deleted
#      Reaction Array now has 788 elements
#      i pointer is in position 3 with id: PERD
# PERD deleted
#      Reaction Array now has 787 elements
#      i pointer is in position 3 with id: DAPDC
# DAPDC deleted
#      Reaction Array now has 786 elements
#      i pointer is in position 3 with id: COCHL
# COCHL deleted
#      Reaction Array now has 785 elements
#      i pointer is in position 3 with id: 3OAR100
# 3OAR100 deleted
#      Reaction Array now has 784 elements
#      i pointer is in position 3 with id: PFK_3
# PFK_3 deleted
#      Reaction Array now has 783 elements
#      i pointer is in position 3 with id: PPK2r
# PPK2r deleted
#      Reaction Array now has 782 elements
#      i pointer is in position 3 with id: ZNabcpp
# ZNabcpp deleted
#      Reaction Array now has 781 elements
#      i pointer is in position 3 with id: GLYDHDA
# GLYDHDA deleted
#      Reaction Array now has 780 elements
#      i pointer is in position 3 with id: ANS
# ANS deleted
#      Reaction Array now has 779 elements
#      i pointer is in position 3 with id: SUCBZL
# SUCBZL deleted
#      Reaction Array now has 778 elements
#      i pointer is in position 3 with id: ADPT
# ADPT deleted
#      Reaction Array now has 777 elements
#      i pointer is in position 3 with id: RNDR3
# RNDR3 deleted
#      Reaction Array now has 776 elements
#      i pointer is in position 3 with id: DHNANT
# DHNANT deleted
#      Reaction Array now has 775 elements
#      i pointer is in position 3 with id: GND
# GND deleted
#      Reaction Array now has 774 elements
#      i pointer is in position 3 with id: O2tcx
# O2tcx deleted
#      Reaction Array now has 773 elements
#      i pointer is in position 3 with id: TRPS3
# TRPS3 deleted
#      Reaction Array now has 772 elements
#      i pointer is in position 3 with id: DNTPPA
# DNTPPA deleted
#      Reaction Array now has 771 elements
#      i pointer is in position 3 with id: HOXGfx
# HOXGfx deleted
#      Reaction Array now has 770 elements
#      i pointer is in position 3 with id: TMPPP
# TMPPP deleted
#      Reaction Array now has 769 elements
#      i pointer is in position 3 with id: TALA
# TALA deleted
#      Reaction Array now has 768 elements
#      i pointer is in position 3 with id: ACONT
# ACONT deleted
#      Reaction Array now has 767 elements
#      i pointer is in position 3 with id: IGPS
# IGPS deleted
#      Reaction Array now has 766 elements
#      i pointer is in position 3 with id: HBZNPT
# HBZNPT deleted
#      Reaction Array now has 765 elements
#      i pointer is in position 3 with id: HSDyi
# HSDyi deleted
#      Reaction Array now has 764 elements
#      i pointer is in position 3 with id: GLYOX
# GLYOX deleted
#      Reaction Array now has 763 elements
#      i pointer is in position 3 with id: CBMD
# CBMD deleted
#      Reaction Array now has 762 elements
#      i pointer is in position 3 with id: AICART
# AICART deleted
#      Reaction Array now has 761 elements
#      i pointer is in position 3 with id: UDPSQS
# UDPSQS deleted
#      Reaction Array now has 760 elements
#      i pointer is in position 3 with id: GK1
# GK1 deleted
#      Reaction Array now has 759 elements
#      i pointer is in position 3 with id: OXADC
# OXADC deleted
#      Reaction Array now has 758 elements
#      i pointer is in position 3 with id: PC6AS
# PC6AS deleted
#      Reaction Array now has 757 elements
#      i pointer is in position 3 with id: PPND
# PPND deleted
#      Reaction Array now has 756 elements
#      i pointer is in position 3 with id: IPDPS
# IPDPS deleted
#      Reaction Array now has 755 elements
#      i pointer is in position 3 with id: H4THDPS
# H4THDPS deleted
#      Reaction Array now has 754 elements
#      i pointer is in position 3 with id: BM_PIGMENTS
# BM_PIGMENTS remained
# 3HAD160 deleted
#      Reaction Array now has 753 elements
#      i pointer is in position 4 with id: HISTDa
# HISTDa deleted
#      Reaction Array now has 752 elements
#      i pointer is in position 4 with id: ADSL1r
# ADSL1r deleted
#      Reaction Array now has 751 elements
#      i pointer is in position 4 with id: H2Otu_syn
# H2Otu_syn deleted
#      Reaction Array now has 750 elements
#      i pointer is in position 4 with id: ADOCBLS
# ADOCBLS deleted
#      Reaction Array now has 749 elements
#      i pointer is in position 4 with id: PDS2
# PDS2 deleted
#      Reaction Array now has 748 elements
#      i pointer is in position 4 with id: ALAALAr
# ALAALAr deleted
#      Reaction Array now has 747 elements
#      i pointer is in position 4 with id: ACOATA
# ACOATA deleted
#      Reaction Array now has 746 elements
#      i pointer is in position 4 with id: GLCP2
# GLCP2 deleted
#      Reaction Array now has 745 elements
#      i pointer is in position 4 with id: GLYCK
# GLYCK deleted
#      Reaction Array now has 744 elements
#      i pointer is in position 4 with id: MAN1PT
# MAN1PT deleted
#      Reaction Array now has 743 elements
#      i pointer is in position 4 with id: DMBZIDS2
# DMBZIDS2 deleted
#      Reaction Array now has 742 elements
#      i pointer is in position 4 with id: CS
# CS deleted
#      Reaction Array now has 741 elements
#      i pointer is in position 4 with id: DMATT
# DMATT deleted
#      Reaction Array now has 740 elements
#      i pointer is in position 4 with id: PSP_L
# PSP_L deleted
#      Reaction Array now has 739 elements
#      i pointer is in position 4 with id: NDPK3
# NDPK3 deleted
#      Reaction Array now has 738 elements
#      i pointer is in position 4 with id: G3PD2
# G3PD2 deleted
#      Reaction Array now has 737 elements
#      i pointer is in position 4 with id: PHYTES
# PHYTES deleted
#      Reaction Array now has 736 elements
#      i pointer is in position 4 with id: MOHMT
# MOHMT deleted
#      Reaction Array now has 735 elements
#      i pointer is in position 4 with id: FBA
# FBA deleted
#      Reaction Array now has 734 elements
#      i pointer is in position 4 with id: BOF
# BOF deleted
#      Reaction Array now has 733 elements
#      i pointer is in position 4 with id: ACLSa
# ACLSa deleted
#      Reaction Array now has 732 elements
#      i pointer is in position 4 with id: ASADi
# ASADi deleted
#      Reaction Array now has 731 elements
#      i pointer is in position 4 with id: PSCVT
# PSCVT deleted
#      Reaction Array now has 730 elements
#      i pointer is in position 4 with id: TYRTA
# TYRTA deleted
#      Reaction Array now has 729 elements
#      i pointer is in position 4 with id: SERAT
# SERAT deleted
#      Reaction Array now has 728 elements
#      i pointer is in position 4 with id: DHFS
# DHFS deleted
#      Reaction Array now has 727 elements
#      i pointer is in position 4 with id: AMPMS3
# AMPMS3 deleted
#      Reaction Array now has 726 elements
#      i pointer is in position 4 with id: ACBIPGT
# ACBIPGT deleted
#      Reaction Array now has 725 elements
#      i pointer is in position 4 with id: ATPM
# ATPM deleted
#      Reaction Array now has 724 elements
#      i pointer is in position 4 with id: SEPHCHCS
# SEPHCHCS deleted
#      Reaction Array now has 723 elements
#      i pointer is in position 4 with id: NMNDA
# NMNDA deleted
#      Reaction Array now has 722 elements
#      i pointer is in position 4 with id: IGPDH
# IGPDH deleted
#      Reaction Array now has 721 elements
#      i pointer is in position 4 with id: OMPDC
# OMPDC deleted
#      Reaction Array now has 720 elements
#      i pointer is in position 4 with id: DCTPD
# DCTPD deleted
#      Reaction Array now has 719 elements
#      i pointer is in position 4 with id: 3OAR80
# 3OAR80 deleted
#      Reaction Array now has 718 elements
#      i pointer is in position 4 with id: 3OAR180
# 3OAR180 deleted
#      Reaction Array now has 717 elements
#      i pointer is in position 4 with id: GLUSfx
# GLUSfx deleted
#      Reaction Array now has 716 elements
#      i pointer is in position 4 with id: NADS2
# NADS2 deleted
#      Reaction Array now has 715 elements
#      i pointer is in position 4 with id: GLUTRR
# GLUTRR deleted
#      Reaction Array now has 714 elements
#      i pointer is in position 4 with id: G1PTT
# G1PTT deleted
#      Reaction Array now has 713 elements
#      i pointer is in position 4 with id: UAMAGS
# UAMAGS deleted
#      Reaction Array now has 712 elements
#      i pointer is in position 4 with id: FOLD3
# FOLD3 deleted
#      Reaction Array now has 711 elements
#      i pointer is in position 4 with id: 3HAD100
# 3HAD100 deleted
#      Reaction Array now has 710 elements
#      i pointer is in position 4 with id: MEHLER
# MEHLER remained
# GALUi deleted
#      Reaction Array now has 709 elements
#      i pointer is in position 5 with id: P5CR
# P5CR deleted
#      Reaction Array now has 708 elements
#      i pointer is in position 5 with id: PQH2tum
# PQH2tum deleted
#      Reaction Array now has 707 elements
#      i pointer is in position 5 with id: ICHORS
# ICHORS deleted
#      Reaction Array now has 706 elements
#      i pointer is in position 5 with id: 3OAS140
# 3OAS140 deleted
#      Reaction Array now has 705 elements
#      i pointer is in position 5 with id: SBP
# SBP deleted
#      Reaction Array now has 704 elements
#      i pointer is in position 5 with id: EAR60y
# EAR60y deleted
#      Reaction Array now has 703 elements
#      i pointer is in position 5 with id: O2tu
# O2tu deleted
#      Reaction Array now has 702 elements
#      i pointer is in position 5 with id: SULabcpp
# SULabcpp deleted
#      Reaction Array now has 701 elements
#      i pointer is in position 5 with id: PPKr
# PPKr deleted
#      Reaction Array now has 700 elements
#      i pointer is in position 5 with id: BM_DNA
# BM_DNA deleted
#      Reaction Array now has 699 elements
#      i pointer is in position 5 with id: UAPGR
# UAPGR deleted
#      Reaction Array now has 698 elements
#      i pointer is in position 5 with id: DHAD1
# DHAD1 deleted
#      Reaction Array now has 697 elements
#      i pointer is in position 5 with id: IPPS
# IPPS deleted
#      Reaction Array now has 696 elements
#      i pointer is in position 5 with id: PPBNGS
# PPBNGS deleted
#      Reaction Array now has 695 elements
#      i pointer is in position 5 with id: PRE3BS
# PRE3BS deleted
#      Reaction Array now has 694 elements
#      i pointer is in position 5 with id: PHYTES2
# PHYTES2 deleted
#      Reaction Array now has 693 elements
#      i pointer is in position 5 with id: 3HAD80
# 3HAD80 deleted
#      Reaction Array now has 692 elements
#      i pointer is in position 5 with id: LTHRK
# LTHRK deleted
#      Reaction Array now has 691 elements
#      i pointer is in position 5 with id: PPS
# PPS deleted
#      Reaction Array now has 690 elements
#      i pointer is in position 5 with id: ADCPS2
# ADCPS2 deleted
#      Reaction Array now has 689 elements
#      i pointer is in position 5 with id: GF6PTA
# GF6PTA deleted
#      Reaction Array now has 688 elements
#      i pointer is in position 5 with id: O2tpp
# O2tpp deleted
#      Reaction Array now has 687 elements
#      i pointer is in position 5 with id: PGMT
# PGMT deleted
#      Reaction Array now has 686 elements
#      i pointer is in position 5 with id: 3OAR140
# 3OAR140 deleted
#      Reaction Array now has 685 elements
#      i pointer is in position 5 with id: NMNS
# NMNS deleted
#      Reaction Array now has 684 elements
#      i pointer is in position 5 with id: NDPK2
# NDPK2 deleted
#      Reaction Array now has 683 elements
#      i pointer is in position 5 with id: AGDI
# AGDI deleted
#      Reaction Array now has 682 elements
#      i pointer is in position 5 with id: LPADSS2
# LPADSS2 deleted
#      Reaction Array now has 681 elements
#      i pointer is in position 5 with id: DPR
# DPR deleted
#      Reaction Array now has 680 elements
#      i pointer is in position 5 with id: H2Otex
# H2Otex deleted
#      Reaction Array now has 679 elements
#      i pointer is in position 5 with id: TKT2
# TKT2 deleted
#      Reaction Array now has 678 elements
#      i pointer is in position 5 with id: DM_for_c
# DM_for_c deleted
#      Reaction Array now has 677 elements
#      i pointer is in position 5 with id: HEX7
# HEX7 deleted
#      Reaction Array now has 676 elements
#      i pointer is in position 5 with id: PPNCL2
# PPNCL2 deleted
#      Reaction Array now has 675 elements
#      i pointer is in position 5 with id: CYTBD4cm
# CYTBD4cm remained
# GLYCOR_nadp deleted
#      Reaction Array now has 674 elements
#      i pointer is in position 6 with id: CHORS
# CHORS deleted
#      Reaction Array now has 673 elements
#      i pointer is in position 6 with id: 3OAR160
# 3OAR160 deleted
#      Reaction Array now has 672 elements
#      i pointer is in position 6 with id: ADMDC
# ADMDC deleted
#      Reaction Array now has 671 elements
#      i pointer is in position 6 with id: PPPGO2
# PPPGO2 deleted
#      Reaction Array now has 670 elements
#      i pointer is in position 6 with id: ASP1DC
# ASP1DC deleted
#      Reaction Array now has 669 elements
#      i pointer is in position 6 with id: DNAMTn2r
# DNAMTn2r deleted
#      Reaction Array now has 668 elements
#      i pointer is in position 6 with id: MI3PP
# MI3PP deleted
#      Reaction Array now has 667 elements
#      i pointer is in position 6 with id: CYSS_2
# CYSS_2 deleted
#      Reaction Array now has 666 elements
#      i pointer is in position 6 with id: PROHX
# PROHX deleted
#      Reaction Array now has 665 elements
#      i pointer is in position 6 with id: FTHFD
# FTHFD deleted
#      Reaction Array now has 664 elements
#      i pointer is in position 6 with id: MEPCT
# MEPCT deleted
#      Reaction Array now has 663 elements
#      i pointer is in position 6 with id: PDX5POi
# PDX5POi deleted
#      Reaction Array now has 662 elements
#      i pointer is in position 6 with id: PPCDC
# PPCDC deleted
#      Reaction Array now has 661 elements
#      i pointer is in position 6 with id: NTD6
# NTD6 deleted
#      Reaction Array now has 660 elements
#      i pointer is in position 6 with id: NNDMBRT
# NNDMBRT deleted
#      Reaction Array now has 659 elements
#      i pointer is in position 6 with id: ASNN
# ASNN deleted
#      Reaction Array now has 658 elements
#      i pointer is in position 6 with id: PRAIS
# PRAIS deleted
#      Reaction Array now has 657 elements
#      i pointer is in position 6 with id: ORNTAC
# ORNTAC deleted
#      Reaction Array now has 656 elements
#      i pointer is in position 6 with id: SUCBZS
# SUCBZS deleted
#      Reaction Array now has 655 elements
#      i pointer is in position 6 with id: HGYDAS
# HGYDAS deleted
#      Reaction Array now has 654 elements
#      i pointer is in position 6 with id: GGDPR
# GGDPR deleted
#      Reaction Array now has 653 elements
#      i pointer is in position 6 with id: ASPCT
# ASPCT deleted
#      Reaction Array now has 652 elements
#      i pointer is in position 6 with id: PPNDH
# PPNDH deleted
#      Reaction Array now has 651 elements
#      i pointer is in position 6 with id: NMNAT
# NMNAT deleted
#      Reaction Array now has 650 elements
#      i pointer is in position 6 with id: ME2
# ME2 deleted
#      Reaction Array now has 649 elements
#      i pointer is in position 6 with id: APRAUR
# APRAUR deleted
#      Reaction Array now has 648 elements
#      i pointer is in position 6 with id: SADT
# SADT deleted
#      Reaction Array now has 647 elements
#      i pointer is in position 6 with id: LDH_D
# LDH_D deleted
#      Reaction Array now has 646 elements
#      i pointer is in position 6 with id: DPCOAK
# DPCOAK deleted
#      Reaction Array now has 645 elements
#      i pointer is in position 6 with id: O2tex
# O2tex deleted
#      Reaction Array now has 644 elements
#      i pointer is in position 6 with id: DPOR
# DPOR deleted
#      Reaction Array now has 643 elements
#      i pointer is in position 6 with id: ARGSL
# ARGSL deleted
#      Reaction Array now has 642 elements
#      i pointer is in position 6 with id: HSK
# HSK deleted
#      Reaction Array now has 641 elements
#      i pointer is in position 6 with id: EAR120y
# EAR120y deleted
#      Reaction Array now has 640 elements
#      i pointer is in position 6 with id: BCAROHX2
# BCAROHX2 remained
# HPPK deleted
#      Reaction Array now has 639 elements
#      i pointer is in position 7 with id: PPNCL3
# PPNCL3 deleted
#      Reaction Array now has 638 elements
#      i pointer is in position 7 with id: AHCi
# AHCi deleted
#      Reaction Array now has 637 elements
#      i pointer is in position 7 with id: G6PDH2r
# G6PDH2r deleted
#      Reaction Array now has 636 elements
#      i pointer is in position 7 with id: MPPM
# MPPM deleted
#      Reaction Array now has 635 elements
#      i pointer is in position 7 with id: CPPPGO2
# CPPPGO2 deleted
#      Reaction Array now has 634 elements
#      i pointer is in position 7 with id: PC17M
# PC17M deleted
#      Reaction Array now has 633 elements
#      i pointer is in position 7 with id: ACCOAC
# ACCOAC deleted
#      Reaction Array now has 632 elements
#      i pointer is in position 7 with id: GLUCYS
# GLUCYS deleted
#      Reaction Array now has 631 elements
#      i pointer is in position 7 with id: CYNL
# CYNL deleted
#      Reaction Array now has 630 elements
#      i pointer is in position 7 with id: CYOOum
# CYOOum remained
# ACLSb deleted
#      Reaction Array now has 629 elements
#      i pointer is in position 8 with id: DNMPPA
# DNMPPA deleted
#      Reaction Array now has 628 elements
#      i pointer is in position 8 with id: METS
# METS deleted
#      Reaction Array now has 627 elements
#      i pointer is in position 8 with id: TRPS2
# TRPS2 deleted
#      Reaction Array now has 626 elements
#      i pointer is in position 8 with id: PRUK
# PRUK deleted
#      Reaction Array now has 625 elements
#      i pointer is in position 8 with id: FNOR
# FNOR remained
# GART deleted
#      Reaction Array now has 624 elements
#      i pointer is in position 9 with id: G5SADs
# G5SADs deleted
#      Reaction Array now has 623 elements
#      i pointer is in position 9 with id: AMPQT
# AMPQT deleted
#      Reaction Array now has 622 elements
#      i pointer is in position 9 with id: SPMDabcpp
# SPMDabcpp deleted
#      Reaction Array now has 621 elements
#      i pointer is in position 9 with id: DHAD2
# DHAD2 deleted
#      Reaction Array now has 620 elements
#      i pointer is in position 9 with id: PRAMPC
# PRAMPC deleted
#      Reaction Array now has 619 elements
#      i pointer is in position 9 with id: 3OAS80
# 3OAS80 deleted
#      Reaction Array now has 618 elements
#      i pointer is in position 9 with id: G1PCTYT
# G1PCTYT deleted
#      Reaction Array now has 617 elements
#      i pointer is in position 9 with id: BM_CELL_WALL
# BM_CELL_WALL deleted
#      Reaction Array now has 616 elements
#      i pointer is in position 9 with id: CA2abcpp
# CA2abcpp deleted
#      Reaction Array now has 615 elements
#      i pointer is in position 9 with id: UHGADA2
# UHGADA2 deleted
#      Reaction Array now has 614 elements
#      i pointer is in position 9 with id: ASPO6
# ASPO6 deleted
#      Reaction Array now has 613 elements
#      i pointer is in position 9 with id: ASPK
# ASPK deleted
#      Reaction Array now has 612 elements
#      i pointer is in position 9 with id: DXPS
# DXPS deleted
#      Reaction Array now has 611 elements
#      i pointer is in position 9 with id: PRATPP
# PRATPP deleted
#      Reaction Array now has 610 elements
#      i pointer is in position 9 with id: DDPGA
# DDPGA deleted
#      Reaction Array now has 609 elements
#      i pointer is in position 9 with id: NH4tpp
# NH4tpp deleted
#      Reaction Array now has 608 elements
#      i pointer is in position 9 with id: PAPSR
# PAPSR deleted
#      Reaction Array now has 607 elements
#      i pointer is in position 9 with id: NAD_H2
# NAD_H2 remained
# CYRDAAT deleted
#      Reaction Array now has 606 elements
#      i pointer is in position 10 with id: NTPP8
# NTPP8 deleted
#      Reaction Array now has 605 elements
#      i pointer is in position 10 with id: PC11M
# PC11M deleted
#      Reaction Array now has 604 elements
#      i pointer is in position 10 with id: ARGabcpp
# ARGabcpp deleted
#      Reaction Array now has 603 elements
#      i pointer is in position 10 with id: ARGOXRum
# ARGOXRum deleted
#      Reaction Array now has 602 elements
#      i pointer is in position 10 with id: PMDPHT
# PMDPHT deleted
#      Reaction Array now has 601 elements
#      i pointer is in position 10 with id: DAPE
# DAPE deleted
#      Reaction Array now has 600 elements
#      i pointer is in position 10 with id: LYCBC1
# LYCBC1 remained
# RB15BPtcx deleted
#      Reaction Array now has 599 elements
#      i pointer is in position 11 with id: GLCBRAN3
# GLCBRAN3 deleted
#      Reaction Array now has 598 elements
#      i pointer is in position 11 with id: DB4PS
# DB4PS deleted
#      Reaction Array now has 597 elements
#      i pointer is in position 11 with id: DXPRIi
# DXPRIi deleted
#      Reaction Array now has 596 elements
#      i pointer is in position 11 with id: GTPCII
# GTPCII deleted
#      Reaction Array now has 595 elements
#      i pointer is in position 11 with id: RBFSa
# RBFSa deleted
#      Reaction Array now has 594 elements
#      i pointer is in position 11 with id: GLUTRS
# GLUTRS deleted
#      Reaction Array now has 593 elements
#      i pointer is in position 11 with id: ALDD2y
# ALDD2y deleted
#      Reaction Array now has 592 elements
#      i pointer is in position 11 with id: EHGLAT
# EHGLAT deleted
#      Reaction Array now has 591 elements
#      i pointer is in position 11 with id: METAT
# METAT deleted
#      Reaction Array now has 590 elements
#      i pointer is in position 11 with id: DHORTS
# DHORTS deleted
#      Reaction Array now has 589 elements
#      i pointer is in position 11 with id: PDX5PS2
# PDX5PS2 deleted
#      Reaction Array now has 588 elements
#      i pointer is in position 11 with id: ARGDC
# ARGDC deleted
#      Reaction Array now has 587 elements
#      i pointer is in position 11 with id: GAPDi_nadp
# GAPDi_nadp deleted
#      Reaction Array now has 586 elements
#      i pointer is in position 11 with id: GLXO3r
# GLXO3r deleted
#      Reaction Array now has 585 elements
#      i pointer is in position 11 with id: PGCD
# PGCD deleted
#      Reaction Array now has 584 elements
#      i pointer is in position 11 with id: AIRC3
# AIRC3 deleted
#      Reaction Array now has 583 elements
#      i pointer is in position 11 with id: UMPK
# UMPK deleted
#      Reaction Array now has 582 elements
#      i pointer is in position 11 with id: CBPS
# CBPS deleted
#      Reaction Array now has 581 elements
#      i pointer is in position 11 with id: 3HAD180
# 3HAD180 deleted
#      Reaction Array now has 580 elements
#      i pointer is in position 11 with id: IMDHT
# IMDHT deleted
#      Reaction Array now has 579 elements
#      i pointer is in position 11 with id: RZ5PP
# RZ5PP deleted
#      Reaction Array now has 578 elements
#      i pointer is in position 11 with id: RBFSb
# RBFSb deleted
#      Reaction Array now has 577 elements
#      i pointer is in position 11 with id: GLNabcpp
# GLNabcpp deleted
#      Reaction Array now has 576 elements
#      i pointer is in position 11 with id: NDPK8
# NDPK8 deleted
#      Reaction Array now has 575 elements
#      i pointer is in position 11 with id: PC6YM
# PC6YM deleted
#      Reaction Array now has 574 elements
#      i pointer is in position 11 with id: DDPA
# DDPA deleted
#      Reaction Array now has 573 elements
#      i pointer is in position 11 with id: ACOTA
# ACOTA deleted
#      Reaction Array now has 572 elements
#      i pointer is in position 11 with id: FBP
# FBP deleted
#      Reaction Array now has 571 elements
#      i pointer is in position 11 with id: MNabc_1
# MNabc_1 deleted
#      Reaction Array now has 570 elements
#      i pointer is in position 11 with id: NTD7
# NTD7 deleted
#      Reaction Array now has 569 elements
#      i pointer is in position 11 with id: MPOMMM
# MPOMMM deleted
#      Reaction Array now has 568 elements
#      i pointer is in position 11 with id: MTHFD
# MTHFD deleted
#      Reaction Array now has 567 elements
#      i pointer is in position 11 with id: PANTS
# PANTS deleted
#      Reaction Array now has 566 elements
#      i pointer is in position 11 with id: TMPK
# TMPK deleted
#      Reaction Array now has 565 elements
#      i pointer is in position 11 with id: ASNS1
# ASNS1 deleted
#      Reaction Array now has 564 elements
#      i pointer is in position 11 with id: AGPR
# AGPR deleted
#      Reaction Array now has 563 elements
#      i pointer is in position 11 with id: KARI_23dhmp
# KARI_23dhmp deleted
#      Reaction Array now has 562 elements
#      i pointer is in position 11 with id: IPMD
# IPMD deleted
#      Reaction Array now has 561 elements
#      i pointer is in position 11 with id: 3PGtcx
# 3PGtcx deleted
#      Reaction Array now has 560 elements
#      i pointer is in position 11 with id: CDPMEK
# CDPMEK deleted
#      Reaction Array now has 559 elements
#      i pointer is in position 11 with id: CITCIa
# CITCIa deleted
#      Reaction Array now has 558 elements
#      i pointer is in position 11 with id: SUCDum
# SUCDum remained
# DVOCHR deleted
#      Reaction Array now has 557 elements
#      i pointer is in position 12 with id: H2CO3_NAt_syn
# H2CO3_NAt_syn deleted
#      Reaction Array now has 556 elements
#      i pointer is in position 12 with id: HEMEOS
# HEMEOS deleted
#      Reaction Array now has 555 elements
#      i pointer is in position 12 with id: ALAD_L
# ALAD_L deleted
#      Reaction Array now has 554 elements
#      i pointer is in position 12 with id: RPE
# RPE deleted
#      Reaction Array now has 553 elements
#      i pointer is in position 12 with id: MPOMT
# MPOMT deleted
#      Reaction Array now has 552 elements
#      i pointer is in position 12 with id: NDHPQRum
# NDHPQRum remained
# UAMAS deleted
#      Reaction Array now has 551 elements
#      i pointer is in position 13 with id: CITCIb
# CITCIb deleted
#      Reaction Array now has 550 elements
#      i pointer is in position 13 with id: BPNT2
# BPNT2 deleted
#      Reaction Array now has 549 elements
#      i pointer is in position 13 with id: BM_COFACTORS
# BM_COFACTORS deleted
#      Reaction Array now has 548 elements
#      i pointer is in position 13 with id: DCTPD2
# DCTPD2 deleted
#      Reaction Array now has 547 elements
#      i pointer is in position 13 with id: HSERTA
# HSERTA deleted
#      Reaction Array now has 546 elements
#      i pointer is in position 13 with id: NDPK1
# NDPK1 deleted
#      Reaction Array now has 545 elements
#      i pointer is in position 13 with id: PGL
# PGL deleted
#      Reaction Array now has 544 elements
#      i pointer is in position 13 with id: EAR160y
# EAR160y deleted
#      Reaction Array now has 543 elements
#      i pointer is in position 13 with id: MECDPDHf
# MECDPDHf deleted
#      Reaction Array now has 542 elements
#      i pointer is in position 13 with id: MTHFR3_1
# MTHFR3_1 deleted
#      Reaction Array now has 541 elements
#      i pointer is in position 13 with id: 3HAD140
# 3HAD140 deleted
#      Reaction Array now has 540 elements
#      i pointer is in position 13 with id: FBA3
# FBA3 deleted
#      Reaction Array now has 539 elements
#      i pointer is in position 13 with id: DAPNH4T
# DAPNH4T deleted
#      Reaction Array now has 538 elements
#      i pointer is in position 13 with id: MG2uabcpp
# MG2uabcpp deleted
#      Reaction Array now has 537 elements
#      i pointer is in position 13 with id: HCO3E_1_cx
# HCO3E_1_cx remained
# ACODA deleted
#      Reaction Array now has 536 elements
#      i pointer is in position 14 with id: GLU5K
# GLU5K deleted
#      Reaction Array now has 535 elements
#      i pointer is in position 14 with id: EAR100y
# EAR100y deleted
#      Reaction Array now has 534 elements
#      i pointer is in position 14 with id: PGM
# PGM deleted
#      Reaction Array now has 533 elements
#      i pointer is in position 14 with id: ASPOb
# ASPOb deleted
#      Reaction Array now has 532 elements
#      i pointer is in position 14 with id: DM_h2_c
# DM_h2_c deleted
#      Reaction Array now has 531 elements
#      i pointer is in position 14 with id: ACS
# ACS deleted
#      Reaction Array now has 530 elements
#      i pointer is in position 14 with id: PKETX
# PKETX deleted
#      Reaction Array now has 529 elements
#      i pointer is in position 14 with id: AMPTASECG
# AMPTASECG deleted
#      Reaction Array now has 528 elements
#      i pointer is in position 14 with id: SHCHCS3
# SHCHCS3 deleted
#      Reaction Array now has 527 elements
#      i pointer is in position 14 with id: ATPPRT
# ATPPRT deleted
#      Reaction Array now has 526 elements
#      i pointer is in position 14 with id: NDH-1(4)um
# NDH-1(4)um remained
# UAGCVT deleted
#      Reaction Array now has 525 elements
#      i pointer is in position 15 with id: TDPGDH
# TDPGDH deleted
#      Reaction Array now has 524 elements
#      i pointer is in position 15 with id: ADSL2r
# ADSL2r deleted
#      Reaction Array now has 523 elements
#      i pointer is in position 15 with id: PRASCSi
# PRASCSi deleted
#      Reaction Array now has 522 elements
#      i pointer is in position 15 with id: MG2tex
# MG2tex deleted
#      Reaction Array now has 521 elements
#      i pointer is in position 15 with id: HPROb
# HPROb deleted
#      Reaction Array now has 520 elements
#      i pointer is in position 15 with id: NTPP2
# NTPP2 deleted
#      Reaction Array now has 519 elements
#      i pointer is in position 15 with id: TRDR
# TRDR deleted
#      Reaction Array now has 518 elements
#      i pointer is in position 15 with id: PKETF
# PKETF deleted
#      Reaction Array now has 517 elements
#      i pointer is in position 15 with id: NDPK6
# NDPK6 deleted
#      Reaction Array now has 516 elements
#      i pointer is in position 15 with id: GLUPRT
# GLUPRT deleted
#      Reaction Array now has 515 elements
#      i pointer is in position 15 with id: PTRCabcpp
# PTRCabcpp deleted
#      Reaction Array now has 514 elements
#      i pointer is in position 15 with id: UPP3MT
# UPP3MT deleted
#      Reaction Array now has 513 elements
#      i pointer is in position 15 with id: DHNCOAS
# DHNCOAS deleted
#      Reaction Array now has 512 elements
#      i pointer is in position 15 with id: MCOATA
# MCOATA deleted
#      Reaction Array now has 511 elements
#      i pointer is in position 15 with id: PMPK
# PMPK deleted
#      Reaction Array now has 510 elements
#      i pointer is in position 15 with id: HMBS
# HMBS deleted
#      Reaction Array now has 509 elements
#      i pointer is in position 15 with id: PGLYCP
# PGLYCP deleted
#      Reaction Array now has 508 elements
#      i pointer is in position 15 with id: UAGAAT2
# UAGAAT2 deleted
#      Reaction Array now has 507 elements
#      i pointer is in position 15 with id: HTHRPDH
# HTHRPDH deleted
#      Reaction Array now has 506 elements
#      i pointer is in position 15 with id: BCT1_syn
# BCT1_syn deleted
#      Reaction Array now has 505 elements
#      i pointer is in position 15 with id: IPDDI
# IPDDI deleted
#      Reaction Array now has 504 elements
#      i pointer is in position 15 with id: GLYALDDy
# GLYALDDy deleted
#      Reaction Array now has 503 elements
#      i pointer is in position 15 with id: CITMS
# CITMS deleted
#      Reaction Array now has 502 elements
#      i pointer is in position 15 with id: IMPC
# IMPC deleted
#      Reaction Array now has 501 elements
#      i pointer is in position 15 with id: OMCDC
# OMCDC deleted
#      Reaction Array now has 500 elements
#      i pointer is in position 15 with id: Htcx
# Htcx deleted
#      Reaction Array now has 499 elements
#      i pointer is in position 15 with id: DHQTi
# DHQTi deleted
#      Reaction Array now has 498 elements
#      i pointer is in position 15 with id: SPODM
# SPODM remained
# MAN6PI deleted
#      Reaction Array now has 497 elements
#      i pointer is in position 16 with id: 3OAS120
# 3OAS120 deleted
#      Reaction Array now has 496 elements
#      i pointer is in position 16 with id: PGAMT
# PGAMT deleted
#      Reaction Array now has 495 elements
#      i pointer is in position 16 with id: ZDS
# ZDS deleted
#      Reaction Array now has 494 elements
#      i pointer is in position 16 with id: PSERT
# PSERT deleted
#      Reaction Array now has 493 elements
#      i pointer is in position 16 with id: HISTP
# HISTP deleted
#      Reaction Array now has 492 elements
#      i pointer is in position 16 with id: NNDPR
# NNDPR deleted
#      Reaction Array now has 491 elements
#      i pointer is in position 16 with id: ADSK
# ADSK deleted
#      Reaction Array now has 490 elements
#      i pointer is in position 16 with id: MECDPS
# MECDPS deleted
#      Reaction Array now has 489 elements
#      i pointer is in position 16 with id: CUabcpp
# CUabcpp deleted
#      Reaction Array now has 488 elements
#      i pointer is in position 16 with id: ADCYRS
# ADCYRS deleted
#      Reaction Array now has 487 elements
#      i pointer is in position 16 with id: RBPCcx
# RBPCcx deleted
#      Reaction Array now has 486 elements
#      i pointer is in position 16 with id: 3HAD40_1
# 3HAD40_1 deleted
#      Reaction Array now has 485 elements
#      i pointer is in position 16 with id: EAR180x
# EAR180x deleted
#      Reaction Array now has 484 elements
#      i pointer is in position 16 with id: GTHRDH
# GTHRDH deleted
#      Reaction Array now has 483 elements
#      i pointer is in position 16 with id: PRAIi
# PRAIi deleted
#      Reaction Array now has 482 elements
#      i pointer is in position 16 with id: CYNTtabcpp
# CYNTtabcpp deleted
#      Reaction Array now has 481 elements
#      i pointer is in position 16 with id: TRSARyr
# TRSARyr deleted
#      Reaction Array now has 480 elements
#      i pointer is in position 16 with id: PTPATi
# PTPATi deleted
#      Reaction Array now has 479 elements
#      i pointer is in position 16 with id: PC6AR
# PC6AR deleted
#      Reaction Array now has 478 elements
#      i pointer is in position 16 with id: Kabcpp
# Kabcpp deleted
#      Reaction Array now has 477 elements
#      i pointer is in position 16 with id: ENO
# ENO deleted
#      Reaction Array now has 476 elements
#      i pointer is in position 16 with id: TDPDRR
# TDPDRR deleted
#      Reaction Array now has 475 elements
#      i pointer is in position 16 with id: PRFGS
# PRFGS deleted
#      Reaction Array now has 474 elements
#      i pointer is in position 16 with id: PC8XM
# PC8XM deleted
#      Reaction Array now has 473 elements
#      i pointer is in position 16 with id: 3OAS60
# 3OAS60 deleted
#      Reaction Array now has 472 elements
#      i pointer is in position 16 with id: GMPS2
# GMPS2 deleted
#      Reaction Array now has 471 elements
#      i pointer is in position 16 with id: RBFK
# RBFK deleted
#      Reaction Array now has 470 elements
#      i pointer is in position 16 with id: NTRIRfx
# NTRIRfx deleted
#      Reaction Array now has 469 elements
#      i pointer is in position 16 with id: GTHPi
# GTHPi deleted
#      Reaction Array now has 468 elements
#      i pointer is in position 16 with id: ARGSS
# ARGSS deleted
#      Reaction Array now has 467 elements
#      i pointer is in position 16 with id: SPTr
# SPTr deleted
#      Reaction Array now has 466 elements
#      i pointer is in position 16 with id: H2Otpp
# H2Otpp deleted
#      Reaction Array now has 465 elements
#      i pointer is in position 16 with id: TDPDRE
# TDPDRE deleted
#      Reaction Array now has 464 elements
#      i pointer is in position 16 with id: GTHOr
# GTHOr deleted
#      Reaction Array now has 463 elements
#      i pointer is in position 16 with id: SHK3Dr
# SHK3Dr deleted
#      Reaction Array now has 462 elements
#      i pointer is in position 16 with id: CYRDAR
# CYRDAR deleted
#      Reaction Array now has 461 elements
#      i pointer is in position 16 with id: ORPT
# ORPT deleted
#      Reaction Array now has 460 elements
#      i pointer is in position 16 with id: GRTT
# GRTT deleted
#      Reaction Array now has 459 elements
#      i pointer is in position 16 with id: TRDRf
# TRDRf remained
# BM_MEM_LIPIDS deleted
#      Reaction Array now has 458 elements
#      i pointer is in position 17 with id: PRPPS
# PRPPS deleted
#      Reaction Array now has 457 elements
#      i pointer is in position 17 with id: KARA1i
# KARA1i deleted
#      Reaction Array now has 456 elements
#      i pointer is in position 17 with id: SPRMS
# SPRMS deleted
#      Reaction Array now has 455 elements
#      i pointer is in position 17 with id: FCLT
# FCLT deleted
#      Reaction Array now has 454 elements
#      i pointer is in position 17 with id: PPA
# PPA deleted
#      Reaction Array now has 453 elements
#      i pointer is in position 17 with id: DHQS
# DHQS deleted
#      Reaction Array now has 452 elements
#      i pointer is in position 17 with id: ANPRT
# ANPRT deleted
#      Reaction Array now has 451 elements
#      i pointer is in position 17 with id: ADK1
# ADK1 deleted
#      Reaction Array now has 450 elements
#      i pointer is in position 17 with id: UPP3S
# UPP3S deleted
#      Reaction Array now has 449 elements
#      i pointer is in position 17 with id: NDPK5
# NDPK5 deleted
#      Reaction Array now has 448 elements
#      i pointer is in position 17 with id: NDHPQRcm
# NDHPQRcm remained
# DHNPA_1 deleted
#      Reaction Array now has 447 elements
#      i pointer is in position 18 with id: NDPK4
# NDPK4 deleted
#      Reaction Array now has 446 elements
#      i pointer is in position 18 with id: RNDR4
# RNDR4 deleted
#      Reaction Array now has 445 elements
#      i pointer is in position 18 with id: NADK
# NADK deleted
#      Reaction Array now has 444 elements
#      i pointer is in position 18 with id: 3OAR40_1
# 3OAR40_1 deleted
#      Reaction Array now has 443 elements
#      i pointer is in position 18 with id: TKT1
# TKT1 deleted
#      Reaction Array now has 442 elements
#      i pointer is in position 18 with id: NO3abcpp
# NO3abcpp deleted
#      Reaction Array now has 441 elements
#      i pointer is in position 18 with id: FE3abcpp
# FE3abcpp deleted
#      Reaction Array now has 440 elements
#      i pointer is in position 18 with id: MOBDabcpp
# MOBDabcpp deleted
#      Reaction Array now has 439 elements
#      i pointer is in position 18 with id: NPHBDC
# NPHBDC deleted
#      Reaction Array now has 438 elements
#      i pointer is in position 18 with id: NPDPS
# NPDPS deleted
#      Reaction Array now has 437 elements
#      i pointer is in position 18 with id: NI2uabcpp
# NI2uabcpp deleted
#      Reaction Array now has 436 elements
#      i pointer is in position 18 with id: HCO3tcx
# HCO3tcx deleted
#      Reaction Array now has 435 elements
#      i pointer is in position 18 with id: RNDR2
# RNDR2 deleted
#      Reaction Array now has 434 elements
#      i pointer is in position 18 with id: KARI
# KARI deleted
#      Reaction Array now has 433 elements
#      i pointer is in position 18 with id: EAR40y
# EAR40y deleted
#      Reaction Array now has 432 elements
#      i pointer is in position 18 with id: NADTRHD
# NADTRHD remained
# DHNCOAT deleted
#      Reaction Array now has 431 elements
#      i pointer is in position 19 with id: BM_PROTEIN
# BM_PROTEIN deleted
#      Reaction Array now has 430 elements
#      i pointer is in position 19 with id: 3OAS100
# 3OAS100 deleted
#      Reaction Array now has 429 elements
#      i pointer is in position 19 with id: G1SAT
# G1SAT deleted
#      Reaction Array now has 428 elements
#      i pointer is in position 19 with id: ILETA
# ILETA deleted
#      Reaction Array now has 427 elements
#      i pointer is in position 19 with id: PDS1
# PDS1 deleted
#      Reaction Array now has 426 elements
#      i pointer is in position 19 with id: UAAGDS
# UAAGDS deleted
#      Reaction Array now has 425 elements
#      i pointer is in position 19 with id: GLCDBRAN3
# GLCDBRAN3 deleted
#      Reaction Array now has 424 elements
#      i pointer is in position 19 with id: HEX1
# HEX1 deleted
#      Reaction Array now has 423 elements
#      i pointer is in position 19 with id: ATPSum
# ATPSum remained
# CHPHYS deleted
#      Reaction Array now has 422 elements
#      i pointer is in position 20 with id: BCAROHX
# BCAROHX remained
# GLYCLTDx deleted
#      Reaction Array now has 421 elements
#      i pointer is in position 21 with id: PIuabcpp
# PIuabcpp deleted
#      Reaction Array now has 420 elements
#      i pointer is in position 21 with id: PC20M
# PC20M deleted
#      Reaction Array now has 419 elements
#      i pointer is in position 21 with id: ADSS
# ADSS deleted
#      Reaction Array now has 418 elements
#      i pointer is in position 21 with id: BM_RNA
# BM_RNA deleted
#      Reaction Array now has 417 elements
#      i pointer is in position 21 with id: DM_dialurate_c
# DM_dialurate_c deleted
#      Reaction Array now has 416 elements
#      i pointer is in position 21 with id: THRPD
# THRPD deleted
#      Reaction Array now has 415 elements
#      i pointer is in position 21 with id: TMDS3
# TMDS3 deleted
#      Reaction Array now has 414 elements
#      i pointer is in position 21 with id: DHFR
# DHFR deleted
#      Reaction Array now has 413 elements
#      i pointer is in position 21 with id: ACGS
# ACGS deleted
#      Reaction Array now has 412 elements
#      i pointer is in position 21 with id: VALTA
# VALTA deleted
#      Reaction Array now has 411 elements
#      i pointer is in position 21 with id: AFAT
# AFAT deleted
#      Reaction Array now has 410 elements
#      i pointer is in position 21 with id: GLYOX_1
# GLYOX_1 deleted
#      Reaction Array now has 409 elements
#      i pointer is in position 21 with id: EAR140y
# EAR140y deleted
#      Reaction Array now has 408 elements
#      i pointer is in position 21 with id: FRTT
# FRTT deleted
#      Reaction Array now has 407 elements
#      i pointer is in position 21 with id: CTPS2
# CTPS2 deleted
#      Reaction Array now has 406 elements
#      i pointer is in position 21 with id: DESAT16a
# DESAT16a deleted
#      Reaction Array now has 405 elements
#      i pointer is in position 21 with id: CO2tex
# CO2tex deleted
#      Reaction Array now has 404 elements
#      i pointer is in position 21 with id: GTHS
# GTHS deleted
#      Reaction Array now has 403 elements
#      i pointer is in position 21 with id: UAGDP
# UAGDP deleted
#      Reaction Array now has 402 elements
#      i pointer is in position 21 with id: DADK
# DADK deleted
#      Reaction Array now has 401 elements
#      i pointer is in position 21 with id: MPOMC1
# MPOMC1 deleted
#      Reaction Array now has 400 elements
#      i pointer is in position 21 with id: Nat_Kpp
# Nat_Kpp deleted
#      Reaction Array now has 399 elements
#      i pointer is in position 21 with id: 3OAS180
# 3OAS180 deleted
#      Reaction Array now has 398 elements
#      i pointer is in position 21 with id: ARGDHpp
# ARGDHpp deleted
#      Reaction Array now has 397 elements
#      i pointer is in position 21 with id: EAR80y
# EAR80y deleted
#      Reaction Array now has 396 elements
#      i pointer is in position 21 with id: ERTHMMOR
# ERTHMMOR deleted
#      Reaction Array now has 395 elements
#      i pointer is in position 21 with id: PDH
# PDH deleted
#      Reaction Array now has 394 elements
#      i pointer is in position 21 with id: MPML
# MPML deleted
#      Reaction Array now has 393 elements
#      i pointer is in position 21 with id: USHD2
# USHD2 deleted
#      Reaction Array now has 392 elements
#      i pointer is in position 21 with id: TPI
# TPI deleted
#      Reaction Array now has 391 elements
#      i pointer is in position 21 with id: DHPPDA
# DHPPDA deleted
# ...
#      i pointer is in position 31 with id: LEUTRS
# LEUTRS deleted
#      Reaction Array now has 179 elements
#      i pointer is in position 31 with id: ILETRS
# ILETRS deleted
#      Reaction Array now has 178 elements
#      i pointer is in position 31 with id: LYSTRS
# LYSTRS deleted
#      Reaction Array now has 177 elements
#      i pointer is in position 31 with id: ALATRS
# ALATRS deleted
#      Reaction Array now has 176 elements
#      i pointer is in position 31 with id: VALTRS
# VALTRS deleted
#      Reaction Array now has 175 elements
#      i pointer is in position 31 with id: FMETTRS
# FMETTRS deleted
#      Reaction Array now has 174 elements
#      i pointer is in position 31 with id: EX_photon410_e
# EX_photon410_e deleted
#      Reaction Array now has 173 elements
#      i pointer is in position 31 with id: EX_photon430_e
# EX_photon430_e deleted
#      Reaction Array now has 172 elements
#      i pointer is in position 31 with id: EX_photon450_e
# EX_photon450_e deleted
#      Reaction Array now has 171 elements
#      i pointer is in position 31 with id: EX_photon470_e
# EX_photon470_e deleted
#      Reaction Array now has 170 elements
#      i pointer is in position 31 with id: EX_photon490_e
# EX_photon490_e deleted
#      Reaction Array now has 169 elements
#      i pointer is in position 31 with id: EX_photon510_e
# EX_photon510_e deleted
#      Reaction Array now has 168 elements
#      i pointer is in position 31 with id: EX_photon530_e
# EX_photon530_e deleted
#      Reaction Array now has 167 elements
#      i pointer is in position 31 with id: EX_photon550_e
# EX_photon550_e deleted
#      Reaction Array now has 166 elements
#      i pointer is in position 31 with id: EX_photon570_e
# EX_photon570_e deleted
#      Reaction Array now has 165 elements
#      i pointer is in position 31 with id: EX_photon590_e
# EX_photon590_e deleted
#      Reaction Array now has 164 elements
#      i pointer is in position 31 with id: EX_photon610_e
# EX_photon610_e deleted
#      Reaction Array now has 163 elements
#      i pointer is in position 31 with id: EX_photon630_e
# EX_photon630_e deleted
#      Reaction Array now has 162 elements
#      i pointer is in position 31 with id: EX_photon650_e
# EX_photon650_e deleted
#      Reaction Array now has 161 elements
#      i pointer is in position 31 with id: EX_photon670_e
# EX_photon670_e deleted
#      Reaction Array now has 160 elements
#      i pointer is in position 31 with id: EX_photon690_e
# EX_photon690_e deleted
#      Reaction Array now has 159 elements
#      i pointer is in position 31 with id: ZXANHX
# ZXANHX remained
# CXANHX remained
# PHOA410um remained
# PHOA430um remained
# PHOA450um remained
# PHOA470um remained
# PHOA490um remained
# PHOA510um remained
# PHOA530um remained
# PHOA550um remained
# PHOA570um remained
# PHOA590um remained
# PHOA610um remained
# PHOA630um remained
# PHOA650um remained
# PHOA670um remained
# PHOA690um remained
# DM_pho_loss_c deleted
#      Reaction Array now has 158 elements
#      i pointer is in position 48 with id: ETCHLAS
# ETCHLAS remained
# ETBCARO remained
# ETCPC remained
# STACPSI remained
# A5PISO deleted
#      Reaction Array now has 157 elements
#      i pointer is in position 52 with id: KDOPS
# KDOPS deleted
#      Reaction Array now has 156 elements
#      i pointer is in position 52 with id: KDOPP
# KDOPP deleted
#      Reaction Array now has 155 elements
#      i pointer is in position 52 with id: KDOCT2
# KDOCT2 deleted
#      Reaction Array now has 154 elements
#      i pointer is in position 52 with id: MOAT
# MOAT deleted
#      Reaction Array now has 153 elements
#      i pointer is in position 52 with id: UAG2E
# UAG2E deleted
#      Reaction Array now has 152 elements
#      i pointer is in position 52 with id: ACGAMT
# ACGAMT deleted
#      Reaction Array now has 151 elements
#      i pointer is in position 52 with id: ACMAMT
# ACMAMT deleted
#      Reaction Array now has 150 elements
#      i pointer is in position 52 with id: ICLIPAS
# ICLIPAS deleted
#      Reaction Array now has 149 elements
#      i pointer is in position 52 with id: ICLIPAabcpp
# ICLIPAabcpp deleted
#      Reaction Array now has 148 elements
#      i pointer is in position 52 with id: OANTS
# OANTS deleted
#      Reaction Array now has 147 elements
#      i pointer is in position 52 with id: OANTIabcpp
# OANTIabcpp deleted
#      Reaction Array now has 146 elements
#      i pointer is in position 52 with id: OANTILpp
# OANTILpp deleted
#      Reaction Array now has 145 elements
#      i pointer is in position 52 with id: COLIPAabcex
# COLIPAabcex deleted
#      Reaction Array now has 144 elements
#      i pointer is in position 52 with id: MPTG
# MPTG deleted
#      Reaction Array now has 143 elements
#      i pointer is in position 52 with id: MPTG2
# MPTG2 deleted
#      Reaction Array now has 142 elements
#      i pointer is in position 52 with id: MCTP2App
# MCTP2App deleted
#      Reaction Array now has 141 elements
#      i pointer is in position 52 with id: MCTP1App
# MCTP1App deleted
#      Reaction Array now has 140 elements
#      i pointer is in position 52 with id: MCTP1Bpp
# MCTP1Bpp deleted
#      Reaction Array now has 139 elements
#      i pointer is in position 52 with id: MDDCP1pp
# MDDCP1pp deleted
#      Reaction Array now has 138 elements
#      i pointer is in position 52 with id: MDDCP2pp
# MDDCP2pp deleted
#      Reaction Array now has 137 elements
#      i pointer is in position 52 with id: MDDCP3pp
# MDDCP3pp deleted
#      Reaction Array now has 136 elements
#      i pointer is in position 52 with id: MDDCP4pp
# MDDCP4pp deleted
#      Reaction Array now has 135 elements
#      i pointer is in position 52 with id: MDDCP5pp
# MDDCP5pp deleted
#      Reaction Array now has 134 elements
#      i pointer is in position 52 with id: MDDEP1pp
# MDDEP1pp deleted
#      Reaction Array now has 133 elements
#      i pointer is in position 52 with id: MDDEP2pp
# MDDEP2pp deleted
#      Reaction Array now has 132 elements
#      i pointer is in position 52 with id: MDDEP3pp
# MDDEP3pp deleted
#      Reaction Array now has 131 elements
#      i pointer is in position 52 with id: MDDEP4pp
# MDDEP4pp deleted
#      Reaction Array now has 130 elements
#      i pointer is in position 52 with id: MLDCP1App
# MLDCP1App deleted
#      Reaction Array now has 129 elements
#      i pointer is in position 52 with id: MLDCP1Bpp
# MLDCP1Bpp deleted
#      Reaction Array now has 128 elements
#      i pointer is in position 52 with id: MLDCP2App
# MLDCP2App deleted
#      Reaction Array now has 127 elements
#      i pointer is in position 52 with id: MLDCP2Bpp
# MLDCP2Bpp deleted
#      Reaction Array now has 126 elements
#      i pointer is in position 52 with id: MLTGY1pp
# MLTGY1pp deleted
#      Reaction Array now has 125 elements
#      i pointer is in position 52 with id: MLTGY2pp
# MLTGY2pp deleted
#      Reaction Array now has 124 elements
#      i pointer is in position 52 with id: MLTGY3pp
# MLTGY3pp deleted
#      Reaction Array now has 123 elements
#      i pointer is in position 52 with id: MLTGY4pp
# MLTGY4pp deleted
#      Reaction Array now has 122 elements
#      i pointer is in position 52 with id: AGM4PA
# AGM4PA deleted
#      Reaction Array now has 121 elements
#      i pointer is in position 52 with id: AGM4PApp
# AGM4PApp deleted
#      Reaction Array now has 120 elements
#      i pointer is in position 52 with id: AGM4PCP
# AGM4PCP deleted
#      Reaction Array now has 119 elements
#      i pointer is in position 52 with id: AGM4PH
# AGM4PH deleted
#      Reaction Array now has 118 elements
#      i pointer is in position 52 with id: AGM3PApp
# AGM3PApp deleted
#      Reaction Array now has 117 elements
#      i pointer is in position 52 with id: AGMH
# AGMH deleted
#      Reaction Array now has 116 elements
#      i pointer is in position 52 with id: AGM3PH
# AGM3PH deleted
#      Reaction Array now has 115 elements
#      i pointer is in position 52 with id: AM4PCP
# AM4PCP deleted
#      Reaction Array now has 114 elements
#      i pointer is in position 52 with id: 4PCP
# 4PCP deleted
#      Reaction Array now has 113 elements
#      i pointer is in position 52 with id: AM3PA
# AM3PA deleted
#      Reaction Array now has 112 elements
#      i pointer is in position 52 with id: AM4PA
# AM4PA deleted
#      Reaction Array now has 111 elements
#      i pointer is in position 52 with id: LADGMDH
# LADGMDH deleted
#      Reaction Array now has 110 elements
#      i pointer is in position 52 with id: UM4PL
# UM4PL deleted
#      Reaction Array now has 109 elements
#      i pointer is in position 52 with id: ALAGLUE
# ALAGLUE deleted
#      Reaction Array now has 108 elements
#      i pointer is in position 52 with id: UM3PL
# UM3PL deleted
#      Reaction Array now has 107 elements
#      i pointer is in position 52 with id: UM4PCP
# UM4PCP deleted
#      Reaction Array now has 106 elements
#      i pointer is in position 52 with id: LALGP
# LALGP deleted
#      Reaction Array now has 105 elements
#      i pointer is in position 52 with id: AGM4Pt2pp
# AGM4Pt2pp deleted
#      Reaction Array now has 104 elements
#      i pointer is in position 52 with id: AGMt2pp
# AGMt2pp deleted
#      Reaction Array now has 103 elements
#      i pointer is in position 52 with id: 4PEPTabcpp
# 4PEPTabcpp deleted
#      Reaction Array now has 102 elements
#      i pointer is in position 52 with id: UAGPT3
# UAGPT3 deleted
#      Reaction Array now has 101 elements
#      i pointer is in position 52 with id: UDCPDP
# UDCPDP deleted
#      Reaction Array now has 100 elements
#      i pointer is in position 52 with id: PAPPT3
# PAPPT3 deleted
#      Reaction Array now has 99 elements
#      i pointer is in position 52 with id: ALAALAD
# ALAALAD deleted
#      Reaction Array now has 98 elements
#      i pointer is in position 52 with id: DALAabcpp
# DALAabcpp deleted
#      Reaction Array now has 97 elements
#      i pointer is in position 52 with id: ALAALAabcpp
# ALAALAabcpp deleted
#      Reaction Array now has 96 elements
#      i pointer is in position 52 with id: 3PEPTabcpp
# 3PEPTabcpp deleted
#      Reaction Array now has 95 elements
#      i pointer is in position 52 with id: PCHLDA430
# PCHLDA430 deleted
#      Reaction Array now has 94 elements
#      i pointer is in position 52 with id: PCHLDA650
# PCHLDA650 deleted
#      Reaction Array now has 93 elements
#      i pointer is in position 52 with id: EX_meoh_e
# EX_meoh_e deleted
#      Reaction Array now has 92 elements
#      i pointer is in position 52 with id: PFOR
# PFOR deleted
#      Reaction Array now has 91 elements
#      i pointer is in position 52 with id: NO2tabcpp
# NO2tabcpp deleted
#      Reaction Array now has 90 elements
#      i pointer is in position 52 with id: NO2tex
# NO2tex deleted
#      Reaction Array now has 89 elements
#      i pointer is in position 52 with id: Htabcpp
# Htabcpp deleted
#      Reaction Array now has 88 elements
#      i pointer is in position 52 with id: ETAPCPSII
# ETAPCPSII remained
# PSICSum remained
# PSIICSum remained
# STCHLPSIum remained
# DEXZEAX remained
# CELLSYN deleted
#      Reaction Array now has 87 elements
#      i pointer is in position 57 with id: ADPGDP
# ADPGDP deleted
#      Reaction Array now has 86 elements
#      i pointer is in position 57 with id: ALCD1
# ALCD1 deleted
#      Reaction Array now has 85 elements
#      i pointer is in position 57 with id: FALGTHLs
# FALGTHLs deleted
#      Reaction Array now has 84 elements
#      i pointer is in position 57 with id: FALDH2
# FALDH2 deleted
#      Reaction Array now has 83 elements
#      i pointer is in position 57 with id: SFGTHi
# SFGTHi deleted
#      Reaction Array now has 82 elements
#      i pointer is in position 57 with id: GGCLUT2
# GGCLUT2 deleted
#      Reaction Array now has 81 elements
#      i pointer is in position 57 with id: OPAH
# OPAH deleted
#      Reaction Array now has 80 elements
#      i pointer is in position 57 with id: ACGAMK
# ACGAMK deleted
#      Reaction Array now has 79 elements
#      i pointer is in position 57 with id: AMANAPEr
# AMANAPEr deleted
#      Reaction Array now has 78 elements
#      i pointer is in position 57 with id: AGDC
# AGDC deleted
#      Reaction Array now has 77 elements
#      i pointer is in position 57 with id: ANHMK
# ANHMK deleted
#      Reaction Array now has 76 elements
#      i pointer is in position 57 with id: ACM6PH
# ACM6PH deleted
#      Reaction Array now has 75 elements
#      i pointer is in position 57 with id: SUCR
# SUCR deleted
#      Reaction Array now has 74 elements
#      i pointer is in position 57 with id: CLt3_1pp
# CLt3_1pp deleted
#      Reaction Array now has 73 elements
#      i pointer is in position 57 with id: Cltex
# Cltex deleted
#      Reaction Array now has 72 elements
#      i pointer is in position 57 with id: EX_cl_e
# EX_cl_e deleted
#      Reaction Array now has 71 elements
#      i pointer is in position 57 with id: Ktu
# Ktu deleted
#      Reaction Array now has 70 elements
#      i pointer is in position 57 with id: FDH6
# FDH6 deleted
#      Reaction Array now has 69 elements
#      i pointer is in position 57 with id: DM_fum_c
# DM_fum_c deleted
#      Reaction Array now has 68 elements
#      i pointer is in position 57 with id: DM_succ_c
# DM_succ_c deleted
#      Reaction Array now has 67 elements
#      i pointer is in position 57 with id: DM_akg_c
# DM_akg_c deleted
#      Reaction Array now has 66 elements
#      i pointer is in position 57 with id: NGAM_D1um
# NGAM_D1um remained
# PSICRum remained
# PSIICRum remained
# DM_ac_c deleted
#      Reaction Array now has 65 elements
#      i pointer is in position 60 with id: DM_lac__D_c
# DM_lac__D_c deleted
#      Reaction Array now has 64 elements
#      i pointer is in position 60 with id: ASPO5
# ASPO5 deleted
#      Reaction Array now has 63 elements
#      i pointer is in position 60 with id: MNHNAtpp
# MNHNAtpp deleted
#      Reaction Array now has 62 elements
#      i pointer is in position 60 with id: PCXHtpp
# PCXHtpp deleted
#      Reaction Array now has 61 elements
#      i pointer is in position 60 with id: NGAM
# NGAM remained
# 61 reactions initially
# 768 metabolites initially
# 785 genes initially
# [<Reaction LYCBC2 at 0x7f3f5ad27100>,
#  <Reaction NDH-1(1)um at 0x7f3f5ad11310>,
#  <Reaction PSIum at 0x7f3f5afe0cd0>,
#  <Reaction BM_PIGMENTS at 0x7f3f5b53c130>,
#  <Reaction MEHLER at 0x7f3f5b4e00a0>,
#  <Reaction CYTBD4cm at 0x7f3f5abb0f10>,
#  <Reaction BCAROHX2 at 0x7f3f5ab58f70>,
#  <Reaction CYOOum at 0x7f3f5ab995b0>,
#  <Reaction FNOR at 0x7f3f5ac022b0>,
#  <Reaction NAD_H2 at 0x7f3f5abeeb20>,
#  <Reaction LYCBC1 at 0x7f3f5abe9820>,
#  <Reaction SUCDum at 0x7f3f5ac48310>,
#  <Reaction NDHPQRum at 0x7f3f5ac48970>,
#  <Reaction HCO3E_1_cx at 0x7f3f5aee8340>,
#  <Reaction NDH-1(4)um at 0x7f3f5ac3c6d0>,
#  <Reaction SPODM at 0x7f3f5ac8e3d0>,
#  <Reaction TRDRf at 0x7f3f5ac76f40>,
#  <Reaction NDHPQRcm at 0x7f3f5ac6f6d0>,
#  <Reaction NADTRHD at 0x7f3f5ac5d790>,
#  <Reaction ATPSum at 0x7f3f5ac56a90>,
#  <Reaction BCAROHX at 0x7f3f5ac56430>,
#  <Reaction CYTBD4um at 0x7f3f5acb6490>,
#  <Reaction CAT at 0x7f3f5acb64c0>,
#  <Reaction PSIIum at 0x7f3f5ae4d040>,
#  <Reaction CBFCum at 0x7f3f5ab59730>,
#  <Reaction PHYPQOX at 0x7f3f5aea66a0>,
#  <Reaction ZISO at 0x7f3f5aea65b0>,
#  <Reaction ZCARDS at 0x7f3f5aea6b20>,
#  <Reaction PLYCOI at 0x7f3f5aea6730>,
#  <Reaction NDH-1(2)um at 0x7f3f5aec13d0>,
#  <Reaction NDH-1(3)um at 0x7f3f5ae507c0>,
#  <Reaction ZXANHX at 0x7f3f5ab17460>,
#  <Reaction CXANHX at 0x7f3f5ab17430>,
#  <Reaction PHOA410um at 0x7f3f5ab172b0>,
#  <Reaction PHOA430um at 0x7f3f5ab17160>,
#  <Reaction PHOA450um at 0x7f3f5ab172e0>,
#  <Reaction PHOA470um at 0x7f3f5ab171f0>,
#  <Reaction PHOA490um at 0x7f3f5ae6a940>,
#  <Reaction PHOA510um at 0x7f3f5ae6a760>,
#  <Reaction PHOA530um at 0x7f3f5ae6ae20>,
#  <Reaction PHOA550um at 0x7f3f5ae6a0d0>,
#  <Reaction PHOA570um at 0x7f3f5ae6ac10>,
#  <Reaction PHOA590um at 0x7f3f5ae6a9a0>,
#  <Reaction PHOA610um at 0x7f3f5ae6a700>,
#  <Reaction PHOA630um at 0x7f3f5ae6a5b0>,
#  <Reaction PHOA650um at 0x7f3f5ae6a370>,
#  <Reaction PHOA670um at 0x7f3f5ae6a460>,
#  <Reaction PHOA690um at 0x7f3f5ae6a220>,
#  <Reaction ETCHLAS at 0x7f3f5aa7af10>,
#  <Reaction ETBCARO at 0x7f3f5aa7aee0>,
#  <Reaction ETCPC at 0x7f3f5aa7adc0>,
#  <Reaction STACPSI at 0x7f3f5aa7a580>,
#  <Reaction ETAPCPSII at 0x7f3f59ca43d0>,
#  <Reaction PSICSum at 0x7f3f59ca46d0>,
#  <Reaction PSIICSum at 0x7f3f59ca4b20>,
#  <Reaction STCHLPSIum at 0x7f3f59caca60>,
#  <Reaction DEXZEAX at 0x7f3f59cac9d0>,
#  <Reaction NGAM_D1um at 0x7f3f59cb6f70>,
#  <Reaction PSICRum at 0x7f3f59cbd040>,
#  <Reaction PSIICRum at 0x7f3f59cbd160>,
#  <Reaction NGAM at 0x7f3f59cbd880>]

# %% [markdown]
# **3.3** Clean the model by discarding the metabolites and genes not used

# %% [markdown]
# ###### Function for identifying a property (<u>such as metabolite or gene</u>) without reactions linked

# %%
def MetBoolByRxn(Metmodel, propname, metproperty):
    Met = getattr(getattr(Metmodel, metproperty), propname)
    length = len(getattr(Met, 'reactions')) 
    if length > 0:
        return True
    else:
        return False

gene = MetBoolByRxn(model, 'Synpcc7942_0001', 'genes')
met = MetBoolByRxn(model, 'o2_c', 'metabolites')

print("gene Synpcc7942_0001 has at less 1 reaction involved?: %s" % gene)
print("metabolite o2_c has at less 1 reaction involved?: %s" % met)
# Out:
# gene Synpcc7942_0001 has at less 1 reaction involved?: False
# metabolite o2_c has at less 1 reaction involved?: True

# %% [markdown]
# ##### Clean the unused metabolites inside the model

# %% [markdown]
# ###### Function to delete property objects through the property list

# %%
def CleanProp(Metmodel, metproperty):
    PropList = getattr(Metmodel, metproperty)
    length = len(PropList)
    print('%s initially has %i %s' % (Metmodel.name, length, metproperty))
    i = 0

    while i < length:
        if MetBoolByRxn(Metmodel, PropList[i].id, metproperty):
            print("metabolite %s has at less 1 reaction involved" % PropList[i].name)
            i += 1
        else:
            print("metabolite %s has been deleted" % PropList[i].name)
            PropList[i].remove_from_model()
            length = len(PropList)
            i = i

# %% [markdown]
# <p style="font-size:11pt">Clean the <i>unused metabolites</i> from model</p>

# %%
model_printProp()

CleanProp(model, 'metabolites')

model_printProp()
# Out:
# 61 reactions initially
# 768 metabolites initially
# 785 genes initially
# Model iJB785 initially has 768 metabolites
# metabolite D-Glucosamine 6-phosphate has been deleted
# metabolite Cys-Gly has been deleted
# metabolite O-Acetyl-L-homoserine has been deleted
# metabolite Oxidized plastocyanin has at less 1 reaction involved
# metabolite Oleoyl-[acyl-carrier protein] has been deleted
# metabolite D-Fructose 1,6-bisphosphate has been deleted
# metabolite Agmatine has been deleted
# metabolite 5-Carboxyamino-1-(5-phospho-D-ribosyl)imidazole has been deleted
# metabolite Phosphoenolpyruvate has been deleted
# metabolite CoA has been deleted
# metabolite Hydrogenobyrinate a,c diamide has been deleted
# metabolite Nicotinate has been deleted
# metabolite D-erythro-3-Methylmalate has been deleted
# metabolite L-Leucine has been deleted
# metabolite S-Adenosyl-L-homocysteine has been deleted
# metabolite D-Ribulose 5-phosphate has been deleted
# metabolite 1,4-Dihydroxy-2-naphthoyl-CoA has been deleted
# metabolite H2O has at less 1 reaction involved
# metabolite Hydrogen sulfide has been deleted
# metabolite Orotate has been deleted
# metabolite D-Glucose 1-phosphate has been deleted
# metabolite (3R)-3-Hydroxydecanoyl-[acyl-carrier protein] has been deleted
# metabolite Sodium has been deleted
# metabolite 2-Phosphoglycolate has been deleted
# metabolite beta-Alanine has been deleted
# metabolite sn-Glycerol 3-phosphate has been deleted
# metabolite Plastoquinol-9 has at less 1 reaction involved
# metabolite LL-2,6-Diaminoheptanedioate has been deleted
# metabolite Dodecanoyl-[acyl-carrier protein] has been deleted
# metabolite 2-Phosphoglycolate has been deleted
# metabolite Thioredoxin disulfide has at less 1 reaction involved
# metabolite 3-Oxododecanoyl-[acp] has been deleted
# metabolite D-Glutamate has been deleted
# metabolite H+ has at less 1 reaction involved
# metabolite dUTP has been deleted
# metabolite 3'-Phosphoadenylyl sulfate has been deleted
# metabolite Magnesium has been deleted
# metabolite Hexadecenoyl-[acyl-carrier protein] has been deleted
# metabolite Oxygen has at less 1 reaction involved
# metabolite Anthranilate has been deleted
# metabolite Dihydropteroate has been deleted
# metabolite trans-Hex-2-enoyl-[acp] has been deleted
# metabolite FMN has been deleted
# metabolite Triphosphate has been deleted
# metabolite UDP has been deleted
# metabolite Citrate has been deleted
# metabolite Acetyl-[acyl-carrier protein] has been deleted
# metabolite UDP-N-acetylmuramoyl-L-alanine has been deleted
# metabolite D-erythro-1-(Imidazol-4-yl)glycerol 3-phosphate has been deleted
# metabolite (2S)-2-Isopropyl-3-oxosuccinate has been deleted
# metabolite L-Lysine has been deleted
# metabolite 3-Phospho-D-glyceroyl phosphate has been deleted
# metabolite GMP has been deleted
# metabolite UTP has been deleted
# metabolite Thioredoxin has at less 1 reaction involved
# metabolite Sulfate has been deleted
# metabolite 5-Amino-6-(5'-phosphoribosylamino)uracil has been deleted
# metabolite 13(1)-Hydroxy-magnesium-protoporphyrin IX 13-monomethyl ester has been deleted
# metabolite Pyridoxal phosphate has been deleted
# metabolite 2-Dehydropantoate has been deleted
# metabolite Adenine has been deleted
# metabolite L-Aspartate has been deleted
# metabolite 2-Succinyl-5-enolpyruvyl-6-hydroxy-3-cyclohexene-1-carboxylate has been deleted
# metabolite N-Acetyl-L-glutamate 5-phosphate has been deleted
# metabolite GDP has at less 1 reaction involved
# metabolite Hydrogenobyrinate has been deleted
# metabolite (9Z)-Hexadecanoyl-[acp] has been deleted
# metabolite O-Phospho-L-serine has been deleted
# metabolite Octanoyl-[acp] has been deleted
# metabolite dTTP has been deleted
# metabolite Sucrose 6-phosphate has been deleted
# metabolite 6-Phospho-D-gluconate has been deleted
# metabolite Glycolaldehyde has been deleted
# metabolite 2-Phospho-4-(cytidine 5'-diphospho)-2-C-methyl-D-erythritol has been deleted
# metabolite CMP has been deleted
# metabolite Protein component of biomass has been deleted
# metabolite Orthophosphate has at less 1 reaction involved
# metabolite Pantothenate has been deleted
# metabolite dUMP has been deleted
# metabolite 13(1)-Oxo-magnesium-protoporphyrin IX 13-monomethyl ester has been deleted
# metabolite (R)-2,3-Dihydroxy-3-methylpentanoate has been deleted
# metabolite GTP has at less 1 reaction involved
# metabolite D-4-Hydroxy-2-oxoglutarate has been deleted
# metabolite 5-(5-Phospho-D-ribosylaminoformimino)-1-(5-phosphoribosyl)-imidazole-4-carboxamide has been deleted
# metabolite D-Mannose 1-phosphate has been deleted
# metabolite 1-Deoxy-D-xylulose 5-phosphate has been deleted
# metabolite (R)-3-Hydroxydodecanoyl-[acp] has been deleted
# metabolite Copper has been deleted
# metabolite Malonyl-[acyl-carrier protein] has been deleted
# metabolite 2-Methyl-4-amino-5-hydroxymethylpyrimidine diphosphate has been deleted
# metabolite 5-Guanidino-2-oxopentanoate has been deleted
# metabolite Phenylpyruvate has been deleted
# metabolite Fe2+ has been deleted
# metabolite Phylloquinone has been deleted
# metabolite trans-Oct-2-enoyl-[acp] has been deleted
# metabolite dGDP has been deleted
# metabolite UDP-N-acetyl-3-(1-carboxyvinyl)-D-glucosamine has been deleted
# metabolite Acetaldehyde has been deleted
# metabolite O2- has at less 1 reaction involved
# metabolite Phytofluene has been deleted
# metabolite 2-Acetolactate has been deleted
# metabolite (R)-3-Hydroxy-3-methyl-2-oxopentanoate has been deleted
# metabolite 4-Aminobenzoate has been deleted
# metabolite Phosphoribosyl-AMP has been deleted
# metabolite Calcium has been deleted
# metabolite Glycolate has been deleted
# metabolite Butyryl-[acp] has been deleted
# metabolite (R)-4'-Phosphopantothenoyl-L-cysteine has been deleted
# metabolite UDP-D-galactose has been deleted
# metabolite D-Fructose 6-phosphate has been deleted
# metabolite (R)-Lactate has been deleted
# metabolite L-Histidine has been deleted
# metabolite Adenosine-GDP-cobinamide has been deleted
# metabolite Sedoheptulose 1,7-bisphosphate has been deleted
# metabolite dCTP has been deleted
# metabolite Tetrahydrofolate has been deleted
# metabolite 1-(5'-Phosphoribosyl)-5-amino-4-(N-succinocarboxamide)-imidazole has been deleted
# metabolite Nickel has been deleted
# metabolite 4,6-Dideoxy-4-oxo-dTDP-D-glucose has been deleted
# metabolite Malonyl-CoA has been deleted
# metabolite Fumarate has at less 1 reaction involved
# metabolite Cell wall component of biomass has been deleted
# metabolite Acyl-carrier protein has been deleted
# metabolite 5,10-Methylenetetrahydrofolate has been deleted
# metabolite H+ has at less 1 reaction involved
# metabolite Dihydrofolate has been deleted
# metabolite dUDP has been deleted
# metabolite 3-Oxotetradecanoyl-[acp] has been deleted
# metabolite tRNA(Glu) has been deleted
# metabolite Precorrin 6X has been deleted
# metabolite S-Adenosylmethioninamine has been deleted
# metabolite (R)-3-Hydroxyhexanoyl-[acp] has been deleted
# metabolite D-4'-Phosphopantothenate has been deleted
# metabolite Pyridine-2,3-dicarboxylate has been deleted
# metabolite trans,trans-Farnesyl diphosphate has been deleted
# metabolite D-Glyceraldehyde has been deleted
# metabolite UDP-N-acetyl-D-glucosamine has been deleted
# metabolite 5-Phosphoribosylamine has been deleted
# metabolite meso-2,6-Diaminoheptanedioate has been deleted
# metabolite GDP-mannose has been deleted
# metabolite 3,4-Dihydroxy-2-butanone 4-phosphate has been deleted
# metabolite Neurosporene has been deleted
# metabolite Acetoacetyl-[acp] has been deleted
# metabolite Acetyl phosphate has been deleted
# metabolite UDP-N-acetylmuramoyl-L-alanyl-D-gamma-glutamyl-meso-2,6-diaminopimelate has been deleted
# metabolite Sedoheptulose 7-phosphate has been deleted
# metabolite Carbamate has been deleted
# metabolite CO2 has at less 1 reaction involved
# metabolite Zeaxanthin has at less 1 reaction involved
# metabolite Putrescine has been deleted
# metabolite ADP has at less 1 reaction involved
# metabolite Nicotinamide has been deleted
# metabolite 3-Amino-2-oxopropyl phosphate has been deleted
# metabolite L-Aspartate 4-semialdehyde has been deleted
# metabolite trans-Dec-2-enoyl-[acp] has been deleted
# metabolite O-Phospho-L-homoserine has been deleted
# metabolite Amylose has been deleted
# metabolite S-Methyl-5-thio-D-ribose 1-phosphate has been deleted
# metabolite D-Ribulose 1,5-bisphosphate has been deleted
# metabolite beta-Cryptoxanthin has at less 1 reaction involved
# metabolite Spermidine has been deleted
# metabolite UDP-6-sulfoquinovose has been deleted
# metabolite Hydrogen has at less 1 reaction involved
# metabolite Adenosyl cobinamide phosphate has been deleted
# metabolite (3Z)-Phycocyanobilin has at less 1 reaction involved
# metabolite N-Carbamoylputrescine has been deleted
# metabolite NADH has at less 1 reaction involved
# metabolite Adenylyl sulfate has been deleted
# metabolite Dephospho-CoA has been deleted
# metabolite D-Xylulose 5-phosphate has been deleted
# metabolite Nitrite has been deleted
# metabolite 4-Hydroxybenzoate has been deleted
# metabolite 3-Oxodecanoyl-[acp] has been deleted
# metabolite 2-Amino-4-hydroxy-6-(D-erythro-1,2,3-trihydroxypropyl)-7,8- has been deleted
# metabolite 5-Amino-6-(5'-phosphoribitylamino)uracil has been deleted
# metabolite Iminoaspartate has been deleted
# metabolite Nicotinamide D-ribonucleotide has been deleted
# metabolite Pigment component of biomass has at less 1 reaction involved
# metabolite 1-(2-Carboxyphenylamino)-1-deoxy-D-ribulose 5-phosphate has been deleted
# metabolite Protochlorophyllide has been deleted
# metabolite Oxygen has at less 1 reaction involved
# metabolite L-Alanine has been deleted
# metabolite (2R,3S)-3-Isopropylmalate has been deleted
# metabolite Pyruvate has been deleted
# metabolite HCO3- has at less 1 reaction involved
# metabolite Pantetheine 4'-phosphate has been deleted
# metabolite Succinate has at less 1 reaction involved
# metabolite 2-Methylmaleate has been deleted
# metabolite H2O has at less 1 reaction involved
# metabolite H+ has at less 1 reaction involved
# metabolite UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-6-carboxy-L-lysyl-D-alanyl-D-alanine has been deleted
# metabolite Plastoquinone-9 has at less 1 reaction involved
# metabolite D-Mannose 6-phosphate has been deleted
# metabolite Cobalt ion has been deleted
# metabolite alpha-D-Glucosamine 1-phosphate has been deleted
# metabolite N-(L-Arginino)succinate has been deleted
# metabolite Glycerone phosphate has been deleted
# metabolite Manganese has been deleted
# metabolite UDP-3-O-(3-hydroxyhexadecanoyl)-D-glucosamine has been deleted
# metabolite Spermine has been deleted
# metabolite 2-Hydroxy-3-oxopropanoate has been deleted
# metabolite 2-Oxobutanoate has been deleted
# metabolite dTMP has been deleted
# metabolite 2-(Formamido)-N1-(5'-phosphoribosyl)acetamidine has been deleted
# metabolite UMP has been deleted
# metabolite 3-Phospho-D-glycerate has been deleted
# metabolite Plastoquinone-9 has at less 1 reaction involved
# metabolite 2-Amino-4-hydroxy-6-(erythro-1,2,3-trihydroxypropyl)dihydropteridinetriphosphate has been deleted
# metabolite 4-Methyl-2-oxopentanoate has been deleted
# metabolite all-trans-Nonaprenyl diphosphate has been deleted
# metabolite (S)-Dihydroorotate has been deleted
# metabolite 3-Oxohexadecanoyl-[acp] has been deleted
# metabolite Glyoxylate has been deleted
# metabolite 2,3,4,5-Tetrahydrodipicolinate has been deleted
# metabolite 1-(5'-Phosphoribosyl)-5-formamido-4-imidazolecarboxamide has been deleted
# metabolite Cobamide coenzyme has been deleted
# metabolite L-Threonine has been deleted
# metabolite Sulfite has been deleted
# metabolite 2-Methyl-6-solanyl-1,4-benzoquinol has been deleted
# metabolite HCO3- has at less 1 reaction involved
# metabolite L-Glutamyl 5-phosphate has been deleted
# metabolite (3R)-3-Hydroxytetradecanoyl-[acyl-carrier protein] has been deleted
# metabolite 4-(Cytidine 5'-diphospho)-2-C-methyl-D-erythritol has been deleted
# metabolite dAMP has been deleted
# metabolite L-histidinal has been deleted
# metabolite Glutathione disulfide has been deleted
# metabolite AMP has been deleted
# metabolite 2,3-Dihydroxy-3-methylbutanoate has been deleted
# metabolite S-Methyl-5-thio-D-ribulose 1-phosphate has been deleted
# metabolite Magnesium protoporphyrin has been deleted
# metabolite CDP has been deleted
# metabolite Decanoyl-[acp] has been deleted
# metabolite 2-C-Methyl-D-erythritol 4-phosphate has been deleted
# metabolite (3R)-3-Hydroxypalmitoyl-[acyl-carrier protein] has been deleted
# metabolite (S)-2-Aceto-2-hydroxybutanoate has been deleted
# metabolite beta-Carotene has at less 1 reaction involved
# metabolite 3-Dehydroquinate has been deleted
# metabolite 4-Amino-4-deoxychorismate has been deleted
# metabolite L-Glutamate has been deleted
# metabolite Biomass metabolite: cofactors and ions has been deleted
# metabolite 3-(4-Hydroxyphenyl)pyruvate has been deleted
# metabolite CTP has been deleted
# metabolite Plastoquinol-9 has at less 1 reaction involved
# metabolite FAD has been deleted
# metabolite (1R,6R)-6-Hydroxy-2-succinylcyclohexa-2,4-diene-1-carboxylate has been deleted
# metabolite 1,4-Dihydroxy-2-naphthoate has been deleted
# metabolite CO2 has at less 1 reaction involved
# metabolite N-Acetyl-L-glutamate 5-semialdehyde has been deleted
# metabolite D-Alanine has been deleted
# metabolite 1-(5'-Phosphoribosyl)-5-amino-4-imidazolecarboxamide has been deleted
# metabolite D-Glucose 6-phosphate has been deleted
# metabolite L-Glutamate 5-semialdehyde has been deleted
# metabolite zeta-Carotene has been deleted
# metabolite Acetate has been deleted
# metabolite Precorrin 3B has been deleted
# metabolite Methylglyoxal has been deleted
# metabolite (S)-3-Methyl-2-oxopentanoic acid has been deleted
# metabolite 5-Deoxy-D-ribose has been deleted
# metabolite L-erythro-4-Hydroxyglutamate has been deleted
# metabolite dGTP has been deleted
# metabolite L-Cysteine has been deleted
# metabolite RNA component of biomass has been deleted
# metabolite L-Histidinol phosphate has been deleted
# metabolite Lycopene has at less 1 reaction involved
# metabolite L-Citrulline has been deleted
# metabolite 2-Amino-4-hydroxy-6-hydroxymethyl-7,8-dihydropteridine has been deleted
# metabolite Pyridoxine phosphate has been deleted
# metabolite D-Fructose has been deleted
# metabolite 2-C-Methyl-D-erythritol 2,4-cyclodiphosphate has been deleted
# metabolite N-Carbamoyl-L-aspartate has been deleted
# metabolite Deamino-NAD+ has been deleted
# metabolite dATP has been deleted
# metabolite N-(5'-Phospho-D-1'-ribulosylformimino)-5-amino-1-(5''-phospho-D-ribosyl)-4-imidazolecarboxamide has been deleted
# metabolite (2E)-Octadecenoyl-[acp] has been deleted
# metabolite Chlorophyll a has at less 1 reaction involved
# metabolite D-Glucose has been deleted
# metabolite Oxygen has been deleted
# metabolite Orotidine 5'-phosphate has been deleted
# metabolite Potassium has been deleted
# metabolite S-Adenosyl-L-methionine has been deleted
# metabolite dTDP-6-deoxy-L-mannose has been deleted
# metabolite 2-Isopropylmaleate has been deleted
# metabolite L-Proline has been deleted
# metabolite Coproporphyrinogen III has been deleted
# metabolite 1-Hydroxy-2-methyl-2-butenyl 4-diphosphate has been deleted
# metabolite Thiamin monophosphate has been deleted
# metabolite CDP-glucose has been deleted
# metabolite Xanthosine 5'-phosphate has been deleted
# metabolite Cob(II)yrinate a,c diamide has been deleted
# metabolite Oxidized ferredoxin has at less 1 reaction involved
# metabolite L-Ornithine has been deleted
# metabolite 2-Amino-7,8-dihydro-4-hydroxy-6-(diphosphooxymethyl)pteridine has been deleted
# metabolite Precorrin 6Y has been deleted
# metabolite L-Glutamine has been deleted
# metabolite 3-Oxohexanoyl-[acp] has been deleted
# metabolite 3-Phospho-D-glycerate has been deleted
# metabolite Heme has been deleted
# metabolite 5,10-Methenyltetrahydrofolate has been deleted
# metabolite Cob(I)yrinate a,c diamide has been deleted
# metabolite Magnesium protoporphyrin monomethyl ester has been deleted
# metabolite DNA component of biomass has been deleted
# metabolite Fe3+ has been deleted
# metabolite Zinc has been deleted
# metabolite Hexanoyl-[acp] has been deleted
# metabolite Prephytoene diphosphate has been deleted
# metabolite (S)-4-Amino-5-oxopentanoate has been deleted
# metabolite Chorismate has been deleted
# metabolite 4-Phospho-D-erythronate has been deleted
# metabolite Heme A has been deleted
# metabolite gamma-L-Glutamyl-L-cysteine has been deleted
# metabolite Dimethylallyl diphosphate has been deleted
# metabolite myo-Inositol has been deleted
# metabolite (2S,4S)-4-Hydroxy-2,3,4,5-tetrahydrodipicolinate has been deleted
# metabolite D-1-Aminopropan-2-ol O-phosphate has been deleted
# metabolite Oxaloacetate has been deleted
# metabolite Nitrate has been deleted
# metabolite UDP-N-acetylmuramoyl-L-alanyl-D-glutamate has been deleted
# metabolite Dialurate has been deleted
# metabolite gamma-Carotene has at less 1 reaction involved
# metabolite L-Serine has been deleted
# metabolite (S)-1-Pyrroline-5-carboxylate has been deleted
# metabolite Diphosphate has been deleted
# metabolite Riboflavin has been deleted
# metabolite L-Tyrosine has been deleted
# metabolite Adenosine 3',5'-bisphosphate has been deleted
# metabolite Oxalate has been deleted
# metabolite 2,5-Diamino-6-(5'-phosphoribosylamino)-4-pyrimidineone has been deleted
# metabolite 3-Nonaprenyl-4-hydroxybenzoate has been deleted
# metabolite H2O has been deleted
# metabolite Precorrin 8X has been deleted
# metabolite 3-Dehydroshikimate has been deleted
# metabolite Dihydroneopterin phosphate has been deleted
# metabolite D-Glycerate has been deleted
# metabolite 5'-Deoxyadenosine has been deleted
# metabolite 2-Dehydro-3-deoxy-D-arabino-heptonate 7-phosphate has been deleted
# metabolite N-Acetyl-L-glutamate has been deleted
# metabolite IMP has been deleted
# metabolite NAD+ has at less 1 reaction involved
# metabolite N6-(1,2-Dicarboxyethyl)-AMP has been deleted
# metabolite Biomass metabolite: glycogen and carbohydrates has been deleted
# metabolite 2-(alpha-Hydroxyethyl)thiamine diphosphate has been deleted
# metabolite 3-(Imidazol-4-yl)-2-oxopropyl phosphate has been deleted
# metabolite 6,7-Dimethyl-8-(1-D-ribityl)lumazine has been deleted
# metabolite D-Glyceraldehyde 3-phosphate has been deleted
# metabolite dADP has been deleted
# metabolite Oxygen has been deleted
# metabolite Reduced FMN has been deleted
# metabolite NADPH has at less 1 reaction involved
# metabolite Carbamoyl phosphate has been deleted
# metabolite 1D-myo-Inositol 3-phosphate has been deleted
# metabolite trans-Tetradec-2-enoyl-[acp] has been deleted
# metabolite D-Glucono-1,5-lactone 6-phosphate has been deleted
# metabolite Protoporphyrin has been deleted
# metabolite Molybdate has been deleted
# metabolite Lipid component of biomass has been deleted
# metabolite Deoxyadenosine has been deleted
# metabolite Biliverdin has been deleted
# metabolite Precorrin 4 has been deleted
# metabolite Geranylgeranyl diphosphate has been deleted
# metabolite Precorrin 3A has been deleted
# metabolite D-Ribulose 1,5-bisphosphate has been deleted
# metabolite (3R)-3-Hydroxybutanoyl-[acyl-carrier protein] has been deleted
# metabolite L-Histidinol has been deleted
# metabolite Prephenate has been deleted
# metabolite Nicotinate D-ribonucleotide has been deleted
# metabolite 3-Oxostearoyl-[acp] has been deleted
# metabolite ATP has at less 1 reaction involved
# metabolite 2,3-Bis(3-hydroxyhexadecanoyl)-beta-D-glucosaminyl 1-phosphate has been deleted
# metabolite 2-Phospho-D-glycerate has been deleted
# metabolite Protoporphyrinogen IX has been deleted
# metabolite Undecaprenyl-diphospho-N-acetylmuramoyl-L-alanyl-D-glutamyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine has been deleted
# metabolite L-Methionine has been deleted
# metabolite Phytoene has at less 1 reaction involved
# metabolite trans-4-Hydroxy-L-proline has been deleted
# metabolite L-1-Pyrroline-3-hydroxy-5-carboxylate has been deleted
# metabolite Heme O has been deleted
# metabolite (R)-S-Lactoylglutathione has been deleted
# metabolite H2O has at less 1 reaction involved
# metabolite Adenosyl cobyrinate hexaamide has been deleted
# metabolite CO has been deleted
# metabolite 2-Succinylbenzoyl-CoA has been deleted
# metabolite D-Erythrose 4-phosphate has been deleted
# metabolite Acetyl-CoA has been deleted
# metabolite L-Asparagine has been deleted
# metabolite (S)-Malate has been deleted
# metabolite Octadecanoyl-[acyl-carrier protein] has been deleted
# metabolite Isochorismate has been deleted
# metabolite (R)-Pantoate has been deleted
# metabolite Phytyl diphosphate has been deleted
# metabolite D-Ribose 5-phosphate has been deleted
# metabolite Geranyl diphosphate has been deleted
# metabolite 2-Oxo-3-hydroxy-4-phosphobutanoate has been deleted
# metabolite Isopentenyl diphosphate has been deleted
# metabolite L-Arginine has been deleted
# metabolite L-Phenylalanine has been deleted
# metabolite N-Acetyl-alpha-D-glucosamine 1-phosphate has been deleted
# metabolite NADP+ has at less 1 reaction involved
# metabolite Indoleglycerol phosphate has been deleted
# metabolite L-Valine has been deleted
# metabolite Dimethylbenzimidazole has been deleted
# metabolite 2-Amino-3-oxo-4-phosphonooxybutyrate has been deleted
# metabolite 3-Methyl-2-oxobutanoic acid has been deleted
# metabolite N1-(5-Phospho-alpha-D-ribosyl)-5,6-dimethylbenzimidazole has been deleted
# metabolite alpha-Ribazole has been deleted
# metabolite 5-Methyltetrahydrofolate has been deleted
# metabolite (3R)-3-Hydroxyoctanoyl-[acyl-carrier protein] has been deleted
# metabolite Divinylprotochlorophyllide has been deleted
# metabolite 10-Formyltetrahydrofolate has been deleted
# metabolite 5-Amino-6-(1-D-ribitylamino)uracil has been deleted
# metabolite Shikimate has been deleted
# metabolite 5'-Phosphoribosylglycinamide has been deleted
# metabolite Formate has been deleted
# metabolite 2-Phytyl-1,4-naphthoquinone has been deleted
# metabolite Shikimate 3-phosphate has been deleted
# metabolite (R)-2-Methylmalate has been deleted
# metabolite UDP-glucose has been deleted
# metabolite 5'-Methylthioadenosine has been deleted
# metabolite dCDP has been deleted
# metabolite Reduced plastocyanin has at less 1 reaction involved
# metabolite Tetradecanoyl-[acp] has been deleted
# metabolite L-Glutamyl-tRNA(Glu) has been deleted
# metabolite Adenosyl cobyrinate a,c diamide has been deleted
# metabolite ammonium ion has been deleted
# metabolite L-Homoserine has been deleted
# metabolite O-Acetyl-L-serine has been deleted
# metabolite Precorrin 5 has been deleted
# metabolite Reduced ferredoxin has at less 1 reaction involved
# metabolite 2-Succinylbenzoate has been deleted
# metabolite 5-Phospho-alpha-D-ribose 1-diphosphate has been deleted
# metabolite 1-(5-Phospho-D-ribosyl)-5-amino-4-imidazolecarboxylate has been deleted
# metabolite dTDP-4-dehydro-6-deoxy-L-mannose has been deleted
# metabolite But-2-enoyl-[acyl-carrier protein] has been deleted
# metabolite Chlorophyllide has been deleted
# metabolite H+ has at less 1 reaction involved
# metabolite Glycine has been deleted
# metabolite Uroporphyrinogen III has been deleted
# metabolite dTDP has been deleted
# metabolite UDP-N-acetylmuramate has been deleted
# metabolite L-Tryptophan has been deleted
# metabolite di-trans,poly-cis-Undecaprenyl diphosphate has been deleted
# metabolite Lipid A Disaccharide (cyanobacterial) has been deleted
# metabolite Hydroxypyruvate has been deleted
# metabolite L-Homocysteine has been deleted
# metabolite 1-(5-Phospho-D-ribosyl)-ATP has been deleted
# metabolite Indole has been deleted
# metabolite Precorrin 2 has been deleted
# metabolite Glycogen has been deleted
# metabolite 5-Aminolevulinate has been deleted
# metabolite Glutathione has been deleted
# metabolite 5'-Phosphoribosyl-N-formylglycinamide has been deleted
# metabolite ADP-glucose has been deleted
# metabolite Aminoimidazole ribotide has been deleted
# metabolite 3-Hydroxyoctadecanoyl-[acp] has been deleted
# metabolite Hydroxymethylbilane has been deleted
# metabolite 5-O-(1-Carboxyvinyl)-3-phosphoshikimate has been deleted
# metabolite L-Threonine O-3-phosphate has been deleted
# metabolite 2-Oxoglutarate has been deleted
# metabolite dTDP-glucose has been deleted
# metabolite Thiamin diphosphate has been deleted
# metabolite trans-Hexadec-2-enoyl-[acp] has been deleted
# metabolite H2O2 has at less 1 reaction involved
# metabolite D-Alanyl-D-alanine has been deleted
# metabolite N-(5-Phospho-D-ribosyl)anthranilate has been deleted
# metabolite trans-Dodec-2-enoyl-[acp] has been deleted
# metabolite Isocitrate has been deleted
# metabolite 3-Oxooctanoyl-[acp] has been deleted
# metabolite 4-Amino-2-methyl-5-phosphomethylpyrimidine has been deleted
# metabolite Adenosine has been deleted
# metabolite 4-Phospho-L-aspartate has been deleted
# metabolite 3-Phosphonooxypyruvate has been deleted
# metabolite Porphobilinogen has been deleted
# metabolite N-Acetylornithine has been deleted
# metabolite L-Isoleucine has been deleted
# metabolite (2S)-2-Isopropylmalate has been deleted
# metabolite O-Phospho-4-hydroxy-L-threonine has been deleted
# metabolite Cyanate has been deleted
# metabolite Plastoquinol-9 has been deleted
# metabolite 4-Methyl-5-[2-(phosphonooxy)ethyl]-1,3-thiazole-2-carboxylate has been deleted
# metabolite DNA 5-methylcytosine has been deleted
# metabolite DNA has been deleted
# metabolite 1,4-alpha-D-glucan has been deleted
# metabolite Cobalt ion has been deleted
# metabolite Zinc has been deleted
# metabolite Sulfate has been deleted
# metabolite Spermidine has been deleted
# metabolite Calcium has been deleted
# metabolite ammonium ion has been deleted
# metabolite L-Arginine has been deleted
# metabolite L-Glutamine has been deleted
# metabolite Manganese has been deleted
# metabolite HCO3- has been deleted
# metabolite Magnesium has been deleted
# metabolite Putrescine has been deleted
# metabolite Fe2+ has been deleted
# metabolite Copper has been deleted
# metabolite Potassium has been deleted
# metabolite Nitrate has been deleted
# metabolite Fe3+ has been deleted
# metabolite Molybdate has been deleted
# metabolite Nickel has been deleted
# metabolite Cyanate has been deleted
# metabolite Orthophosphate has been deleted
# metabolite H2O has been deleted
# metabolite Oxygen has been deleted
# metabolite CO2 has been deleted
# metabolite L-Histidine has been deleted
# metabolite Cobalt ion has been deleted
# metabolite Zinc has been deleted
# metabolite Sulfate has been deleted
# metabolite Spermidine has been deleted
# metabolite Calcium has been deleted
# metabolite ammonium ion has been deleted
# metabolite L-Arginine has been deleted
# metabolite L-Glutamine has been deleted
# metabolite Manganese has been deleted
# metabolite HCO3- has been deleted
# metabolite Magnesium has been deleted
# metabolite Putrescine has been deleted
# metabolite Fe2+ has been deleted
# metabolite Copper has been deleted
# metabolite Potassium has been deleted
# metabolite Nitrate has been deleted
# metabolite Fe3+ has been deleted
# metabolite Molybdate has been deleted
# metabolite Nickel has been deleted
# metabolite Sodium has been deleted
# metabolite Cyanate has been deleted
# metabolite CO2 has been deleted
# metabolite H+ has been deleted
# metabolite Sodium has been deleted
# metabolite Orthophosphate has been deleted
# metabolite 2,3-diketo-5-methylthio-1-phosphopentane has been deleted
# metabolite 1,2-Dihydroxy-5-(methylthio)pent-1-en-3-one has been deleted
# metabolite 4-Methylthio-2-oxobutanoic acid has been deleted
# metabolite 9,15,9-tricis-zeta-Carotene has at less 1 reaction involved
# metabolite 9,9-dicis-zeta-Carotene has at less 1 reaction involved
# metabolite 7,9,7,9-tetracis-Lycopene has at less 1 reaction involved
# metabolite pheophytin a has been deleted
# metabolite pheophorbide a has been deleted
# metabolite phytol has been deleted
# metabolite red chlorophyll catabolite has been deleted
# metabolite 6-pyruvoyl-5,6,7,8-tetrahydropterin has been deleted
# metabolite (6R)-5,6,7,8-tetrahydrobiopterin has been deleted
# metabolite 1-O-(L-erythro-biopterin-2-yl)-a-glucose has been deleted
# metabolite Thiamine biosynthesis intermediate 3 has been deleted
# metabolite Thiamine biosynthesis intermediate 2 has been deleted
# metabolite Thiamine biosynthesis intermediate 1 has been deleted
# metabolite Thiamine biosynthesis intermediate 4 has been deleted
# metabolite Thiamine biosynthesis intermediate 5 has been deleted
# metabolite Iminoglycine has been deleted
# metabolite 2-[(2R,5Z)-2-Carboxy-4-methylthiazol-5(2H)-ylidene]ethyl phosphate has been deleted
# metabolite siroheme has been deleted
# metabolite Malonyl-CoA methyl ester has been deleted
# metabolite 3-Oxo-glutaryl-[acyl-carrier protein] methyl ester has been deleted
# metabolite 3-Hydroxyglutaryl-[acyl-carrier protein] methyl ester has been deleted
# metabolite Enoylglutaryl-[acyl-carrier protein] methyl ester has been deleted
# metabolite Glutaryl-[acyl-carrier protein] methyl ester has been deleted
# metabolite 3-Oxo-pimeloyl-[acyl-carrier protein] methyl ester has been deleted
# metabolite 3-Hydroxypimeloyl-[acyl-carrier protein] methyl ester has been deleted
# metabolite Enoylpimeloyl-[acyl-carrier protein] methyl ester has been deleted
# metabolite Pimeloyl-[acyl-carrier protein] methyl ester has been deleted
# metabolite Pimeloyl-[acyl-carrier protein] has been deleted
# metabolite Methanol has been deleted
# metabolite 8-Amino-7-oxononanoate has been deleted
# metabolite 7,8-Diaminononanoate has been deleted
# metabolite S-Adenosyl-4-methylthio-2-oxobutanoate has been deleted
# metabolite Dethiobiotin has been deleted
# metabolite Biotin has been deleted
# metabolite Biotinyl 5 AMP C20H27N7O9PS has been deleted
# metabolite apo-carboxylase has been deleted
# metabolite Holo-[carboxylase] has been deleted
# metabolite Octanoate (protein bound) has been deleted
# metabolite Lipoate (protein bound) has been deleted
# metabolite Lipoate has been deleted
# metabolite Lipoyl-AMP has been deleted
# metabolite Methanol has been deleted
# metabolite Methanol has been deleted
# metabolite 6-carboxy-5,6,7,8-tetrahydropterin has been deleted
# metabolite 7-deaza-7-carboxyguanine has been deleted
# metabolite 7-cyano-7-carbaguanine has been deleted
# metabolite 7-aminomethyl-7-deazaguanine has been deleted
# metabolite 7-aminomethyl-7-deazaguaninyl tRNA has been deleted
# metabolite epoxyquenosine34 tRNA has been deleted
# metabolite quenosine34 tRNA has been deleted
# metabolite Uracil has been deleted
# metabolite UDP-D-glucuronate has been deleted
# metabolite UDP-D-xylose has been deleted
# metabolite GDP-4-dehydro-6-deoxy-D-mannose has been deleted
# metabolite GDP-L-fucose has been deleted
# metabolite Glycerol has been deleted
# metabolite CDP-4-dehydro-6-deoxy-D-glucose has been deleted
# metabolite Sucrose has been deleted
# metabolite Octadecanoate (n-C18:0) has been deleted
# metabolite Octadecanal C18H36O has been deleted
# metabolite Heptadecane has at less 1 reaction involved
# metabolite 1-Hexadecanoyl-sn-glycerol-3-phosphate has been deleted
# metabolite 1-9-Hexadecenoyl-sn-glycerol-3-phosphate has been deleted
# metabolite 1-9-Octadecenoyl-sn-glycerol-3-phosphate has been deleted
# metabolite 1-hexadecanoyl-2-hexadecanoyl-sn-glycerol-3-phosphate has been deleted
# metabolite 1-9-Hexadecenoyl-2-Hexadecanoyl-sn-glycerol-3-phosphate has been deleted
# metabolite 1-9-Hexadecenoyl-2-9-Hexadecenoyl-sn-glycerol-3-phosphate has been deleted
# metabolite 1-9-Octadecenoyl-2-9-Hexadecenoyl-sn-glycerol-3-phosphate has been deleted
# metabolite 1-9-Octadecenoyl-2-Hexadecanoyl-sn-glycerol-3-phosphate has been deleted
# metabolite 1,2-Diacyl-sn-glycerol(16:0/16:0) has been deleted
# metabolite 1,2-Diacyl-sn-glycerol(16:1(9Z)/16:0) has been deleted
# metabolite 1,2-Diacyl-sn-glycerol(16:1(9Z)/16:1(9Z)) has been deleted
# metabolite 1,2-Diacyl-sn-glycerol(18:1(9Z)/16:1(9Z)) has been deleted
# metabolite 1,2-Diacyl-sn-glycerol(18:1(9Z)/16:0) has been deleted
# metabolite Sulfoquinovosyl diacylglycerol(16:0/16:0) has been deleted
# metabolite Sulfoquinovosyl diacylglycerol(16:1(9Z)/16:0) has been deleted
# metabolite 1,2-Diacyl-3-O-galactosyl-sn-glycerol(16:1(9Z)/16:0) has been deleted
# metabolite Digalactosyl-diacylglycerol(16:1(9Z)/16:0) has been deleted
# metabolite Digalactosyl-diacylglycerol(16:1(9Z)/16:1(9Z)) has been deleted
# metabolite 1,2-Diacyl-3-O-galactosyl-sn-glycerol(16:1(9Z)/16:1(9Z)) has been deleted
# metabolite Digalactosyl-diacylglycerol(18:1(9Z)/16:1(9Z)) has been deleted
# metabolite 1,2-Diacyl-3-O-galactosyl-sn-glycerol(18:1(9Z)/16:1(9Z)) has been deleted
# metabolite CDP-1,2-diacyl-sn-glycerol(18:1(9Z)/16:0) has been deleted
# metabolite Phosphatidylglycerophosphate(18:1(9Z)/16:0) has been deleted
# metabolite Phosphatidylglycerol(18:1(9Z)/16:0) has been deleted
# metabolite 1,2-Diacyl-3-O-(beta-D-glucopyranosyl)-sn-glycerol(16:1(9Z)/16:0) has been deleted
# metabolite 1,2-Diacyl-3-O-(beta-D-glucopyranosyl)-sn-glycerol(16:1(9Z)/16:1(9Z)) has been deleted
# metabolite 1,2-Diacyl-3-O-(beta-D-glucopyranosyl)-sn-glycerol(18:1(9Z)/16:1(9Z)) has been deleted
# metabolite 1,2-Diacyl-3-O-(beta-D-glucopyranosyl)-sn-glycerol(18:1(9Z)/16:0) has been deleted
# metabolite 1,2-Diacyl-3-O-galactosyl-sn-glycerol(18:1(9Z)/16:0) has been deleted
# metabolite Digalactosyl-diacylglycerol(18:1(9Z)/16:0) has been deleted
# metabolite L-Glutaminyl-tRNA(Gln) has been deleted
# metabolite tRNA(Gln) has been deleted
# metabolite tRNA(Tyr) has been deleted
# metabolite L-Tyrosyl-tRNA(Tyr) has been deleted
# metabolite tRNA(Met) has been deleted
# metabolite L-Methionyl-tRNA has been deleted
# metabolite tRNA(Ser) has been deleted
# metabolite L-Seryl-tRNA(Ser) has been deleted
# metabolite Glycyl-tRNA(Gly) has been deleted
# metabolite tRNA(Gly) has been deleted
# metabolite L-Prolyl-tRNA(Pro) has been deleted
# metabolite tRNA(Pro) has been deleted
# metabolite tRNA(Cys) has been deleted
# metabolite L-Cysteinyl-tRNA(Cys) has been deleted
# metabolite tRNA(Arg) has been deleted
# metabolite L-Arginyl-tRNA(Arg) has been deleted
# metabolite tRNA(Trp) has been deleted
# metabolite L-Tryptophanyl-tRNA(Trp) has been deleted
# metabolite L-Phenylalanyl-tRNA(Phe) has been deleted
# metabolite tRNA(Phe) has been deleted
# metabolite tRNA(His) has been deleted
# metabolite L-Histidyl-tRNA(His) has been deleted
# metabolite tRNA(Asn) has been deleted
# metabolite L-Asparaginyl-tRNA(Asn) has been deleted
# metabolite L-Aspartyl-tRNA(Asp) has been deleted
# metabolite tRNA(Asp) has been deleted
# metabolite tRNA(Thr) has been deleted
# metabolite L-Threonyl-tRNA(Thr) has been deleted
# metabolite tRNA(Leu) has been deleted
# metabolite L-Leucyl-tRNA has been deleted
# metabolite tRNA(Ile) has been deleted
# metabolite L-Isoleucyl-tRNA(Ile) has been deleted
# metabolite tRNA(Lys) has been deleted
# metabolite L-Lysyl-tRNA has been deleted
# metabolite L-Alanyl-tRNA(Ala) has been deleted
# metabolite tRNA(Ala) has been deleted
# metabolite L-Valyl-tRNA(Val) has been deleted
# metabolite tRNA(Val) has been deleted
# metabolite N-Formylmethionyl-tRNA has been deleted
# metabolite photon (400nm-420nm) has at less 1 reaction involved
# metabolite photon (420nm-440nm) has at less 1 reaction involved
# metabolite photon (440nm-460nm) has at less 1 reaction involved
# metabolite photon (460nm-480nm) has at less 1 reaction involved
# metabolite photon (480nm-500nm) has at less 1 reaction involved
# metabolite photon (500nm-520nm) has at less 1 reaction involved
# metabolite photon (520nm-540nm) has at less 1 reaction involved
# metabolite photon (540nm-560nm) has at less 1 reaction involved
# metabolite photon (560nm-580nm) has at less 1 reaction involved
# metabolite photon (580nm-600nm) has at less 1 reaction involved
# metabolite photon (600nm-620nm) has at less 1 reaction involved
# metabolite photon (620nm-640nm) has at less 1 reaction involved
# metabolite photon (640nm-660nm) has at less 1 reaction involved
# metabolite photon (660nm-680nm) has at less 1 reaction involved
# metabolite photon (680nm-700nm) has at less 1 reaction involved
# metabolite caloxanthin has at less 1 reaction involved
# metabolite nostoxanthin has at less 1 reaction involved
# metabolite Excited chlorophyll A, Soret band (short wavelength) has at less 1 reaction involved
# metabolite Excited beta-carotene has at less 1 reaction involved
# metabolite Excited phycocyanin has at less 1 reaction involved
# metabolite Excited allocyanobilin (phycobilisome core) has at less 1 reaction involved
# metabolite Allocyanobilin (phycobilisome core) has at less 1 reaction involved
# metabolite Photosystem I excited chlorophyll A, Qy band (long wavelength) has at less 1 reaction involved
# metabolite Photon energy loss (heat/fluorescence) has at less 1 reaction involved
# metabolite UDP-2,3-bis(3-hydroxyhexadecanoyl)glucosamine has been deleted
# metabolite UDP-3-O-(3-hydroxyhexadecanoyl)-N-acetylglucosamine has been deleted
# metabolite D-Arabinose 5-phosphate has been deleted
# metabolite 3-Deoxy-D-manno-octulosonate 8-phosphate has been deleted
# metabolite 3-Deoxy-D-manno-2-octulosonate has been deleted
# metabolite CMP-3-deoxy-D-manno-octulosonate has been deleted
# metabolite UDP-N-acetyl-D-mannosamine has been deleted
# metabolite Undecaprenyl phosphate has been deleted
# metabolite Undecaprenyl diphospho N-acetyl-glucosamine has been deleted
# metabolite KDO-lipid IV A (Synechococcus elongatus 7942) has been deleted
# metabolite Undecaprenyl-diphospho-N-acetylglucosamine-N-acetylmannosamine has been deleted
# metabolite Inner core oligosaccharide lipid A (Synechococcus elongatus 7942) has been deleted
# metabolite Inner core oligosaccharide lipid A (Synechococcus elongatus 7942) has been deleted
# metabolite O-antigen oligosaccharide (Synechococcus elongatus 7942) has been deleted
# metabolite O-antigen oligosaccharide (Synechococcus elongatus 7942) has been deleted
# metabolite O-antigen bound to core oligosaccharide lipid A (Synechococcus elongatus 7942) has been deleted
# metabolite O-antigen bound to core oligosaccharide lipid A (Synechococcus elongatus 7942) has been deleted
# metabolite Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-ala-D-glu-meso-2,6-diaminopimeloyl-D-ala-D-ala has been deleted
# metabolite Two linked disacharide pentapeptide murein units (uncrosslinked, middle of chain) has been deleted
# metabolite Three linked disacharide pentapeptide murein units (uncrosslinked, middle of chain) has been deleted
# metabolite D-Alanine has been deleted
# metabolite Three disacharide linked murein units (pentapeptide crosslinked tetrapeptide (A2pm->D-ala) tetrapeptide corsslinked tetrapeptide (A2pm->D-ala)) (middle of chain) has been deleted
# metabolite Two disacharide linked murein units, pentapeptide crosslinked tetrapeptide (A2pm->D-ala) (middle of chain) has been deleted
# metabolite D-Alanyl-D-alanine has been deleted
# metabolite Two disacharide linked murein units, pentapeptide corsslinked tripeptide (A2pm->A2pm) (middle of chain) has been deleted
# metabolite Two disacharide linked murein units, tetrapeptide corsslinked tetrapeptide (A2pm->D-ala) (middle of chain) has been deleted
# metabolite Three disacharide linked murein units (tetrapeptide crosslinked tetrapeptide (A2pm->D-ala) & tetrapeptide corsslinked tetrapeptide (A2pm->D-ala)) (middle of chain) has been deleted
# metabolite Two linked disacharide pentapeptide and tetrapeptide murein units (uncrosslinked, middle of chain) has been deleted
# metabolite Two linked disacharide tetrapeptide murein units (uncrosslinked, middle of chain) has been deleted
# metabolite Two linked disacharide tetrapeptide and tripeptide murein units (uncrosslinked, middle of chain) has been deleted
# metabolite Two linked disacharide pentapeptide and tripeptide murein units (uncrosslinked, middle of chain) has been deleted
# metabolite Two disacharide linked murein units, tripeptide crosslinked tetrapeptide (A2pm->D-ala) (middle of chain) has been deleted
# metabolite Three disacharide linked murein units (tetrapeptide crosslinked tetrapeptide (A2pm->D-ala), one uncrosslinked tetrapaptide) (middle of chain) has been deleted
# metabolite Two linked disacharide tripeptide murein units (uncrosslinked, middle of chain) has been deleted
# metabolite N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tetrapeptide has been deleted
# metabolite N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tripeptide has been deleted
# metabolite N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramic acid has been deleted
# metabolite L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate-D-alanine has been deleted
# metabolite N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tetrapeptide has been deleted
# metabolite N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramic acid has been deleted
# metabolite L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate-D-alanine has been deleted
# metabolite N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tripeptide has been deleted
# metabolite N-Acetyl-D-glucosamine has been deleted
# metabolite 1,6-anhydrous-N-Acetylmuramyl-tetrapeptide has been deleted
# metabolite L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate has been deleted
# metabolite 1,6-anhydrous-N-Acetylmuramate has been deleted
# metabolite 1,6-anhydrous-N-Acetylmuramyl-tripeptide has been deleted
# metabolite L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate has been deleted
# metabolite L-alanine-D-glutamate has been deleted
# metabolite UDP-N-acetylmuramoyl-L-alanyl-D-gamma-glutamyl-meso-2,6-diaminopimelate-D-alanine has been deleted
# metabolite L-alanine-L-glutamate has been deleted
# metabolite Excited protochlorophyllide has been deleted
# metabolite Flavodoxin (oxidized) has been deleted
# metabolite Flavodoxin (reduced) has been deleted
# metabolite 5-Guanidino-2-oxopentanoate has been deleted
# metabolite H2O2 has been deleted
# metabolite L-Leucine has been deleted
# metabolite L-Leucine has been deleted
# metabolite Nitrite has been deleted
# metabolite Nitrite has been deleted
# metabolite Zeaxanthin (excited) has at less 1 reaction involved
# metabolite Photosystem II excited chlorophyll A, Qy band (long wavelength) has at less 1 reaction involved
# metabolite PSI reaction center P700 has at less 1 reaction involved
# metabolite PSI reaction center P700, excited has at less 1 reaction involved
# metabolite PSII reaction center P680, excited has at less 1 reaction involved
# metabolite PSII reaction center P680 has at less 1 reaction involved
# metabolite Cellulose (beta-1,4-glucan) has been deleted
# metabolite Formaldehyde has been deleted
# metabolite Hydroxymethylglutathione has been deleted
# metabolite S-Formylglutathione has been deleted
# metabolite 5-Oxoproline has been deleted
# metabolite N-Acetyl-D-glucosamine 6-phosphate has been deleted
# metabolite N-Acetyl-D-mannosamine 6-phosphate has been deleted
# metabolite N-acetylmuramate 6-phosphate has been deleted
# metabolite Chloride has been deleted
# metabolite Chloride has been deleted
# metabolite Chloride has been deleted
# metabolite Potassium has been deleted
# metabolite PSII D1 protein has at less 1 reaction involved
# metabolite Damaged PSII D1 protein has at less 1 reaction involved
# 61 reactions initially
# 82 metabolites initially
# 785 genes initially

# %% [markdown]
# <p style="font-size:11pt">Clean the <i>unused genes</i> from model</p>

# %%
model_printProp()

CleanProp(model, 'genes')

model_printProp()
# Out:
# 61 reactions initially
# 82 metabolites initially
# 147 genes initially
# Model iJB785 initially has 147 genes
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# metabolite  has at less 1 reaction involved
# 61 reactions initially
# 82 metabolites initially
# 147 genes initially

# %%
# Out:
# <Model iJB785 at 0x7f3f5acf99d0>
